# %%
import pandas as pd
import numpy as np

urineDS=pd.read_csv("/content/drive/MyDrive/Grad2/lastUrine.csv")
urineDS=urineDS.iloc[:,1:]

from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

urineOutput=urineDS.iloc[2:,1:2]
urineInput=urineDS.iloc[2:,4:201]

data = urineInput
scaler = StandardScaler()
scaler.fit(data)
urineInput=scaler.transform(data)
#urineInput=min_max_scaler.fit_transform(data)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(urineInput, urineOutput, test_size=0.33, random_state=0)

# %%
X_train=X_train.astype(np.float64)
X_test=X_test.astype(np.float64)
y_train=y_train.astype(np.float64)
y_test=y_test.astype(np.float64)

X_train=X_train.astype(np.int64)
y_train=y_train.astype(np.int64)
X_train=X_train.astype(np.float64)
y_train=y_train.astype(np.float64)
print(y_train)
# Out:
#      Unnamed: 1
# 231        46.0
# 20         52.0
# 169        25.0
# 254        50.0
# 126        73.0
# ..          ...
# 253        30.0
# 194        60.0
# 119        61.0
# 49         61.0
# 174        62.0
#
# [201 rows x 1 columns]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Flatten,concatenate

from tensorflow.keras.optimizers import Adam
from keras.layers import Dropout
import keras
from matplotlib import pyplot as plt

model3 = Sequential()
model3.add(Conv1D(256, 3, activation='relu', input_shape=(197, 1)))
model3.add(Conv1D(256, 3, activation='relu'))
model3.add(Dropout(0.25))
model3.add(MaxPooling1D(2))
model3.add(Conv1D(128, 3, activation='relu'))
model3.add(MaxPooling1D(2))
model3.add(Dropout(0.25))
model3.add(Conv1D(64, 3, activation='relu'))
model3.add(MaxPooling1D(2))
model3.add(Dropout(0.5))
model3.add(Flatten())
model3.add(Dense(16, activation='relu'))
model3.add(Dense(1, activation='relu'))
model3.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_absolute_error'])

# %%
history =model3.fit(X_train,y_train, batch_size=32, epochs=150, validation_split=0.1)
# Out:
# Epoch 1/150
# 6/6 [==============================] - 2s 263ms/step - loss: 46.9341 - mean_absolute_error: 46.9341 - val_loss: 44.6829 - val_mean_absolute_error: 44.6829
# Epoch 2/150
# 6/6 [==============================] - 1s 227ms/step - loss: 43.0717 - mean_absolute_error: 43.0717 - val_loss: 34.3388 - val_mean_absolute_error: 34.3388
# Epoch 3/150
# 6/6 [==============================] - 1s 224ms/step - loss: 22.5506 - mean_absolute_error: 22.5506 - val_loss: 17.1935 - val_mean_absolute_error: 17.1935
# Epoch 4/150
# 6/6 [==============================] - 1s 225ms/step - loss: 17.5669 - mean_absolute_error: 17.5669 - val_loss: 23.5389 - val_mean_absolute_error: 23.5389
# Epoch 5/150
# 6/6 [==============================] - 1s 224ms/step - loss: 19.2189 - mean_absolute_error: 19.2189 - val_loss: 19.6559 - val_mean_absolute_error: 19.6559
# Epoch 6/150
# 6/6 [==============================] - 1s 227ms/step - loss: 16.7052 - mean_absolute_error: 16.7052 - val_loss: 18.1826 - val_mean_absolute_error: 18.1826
# Epoch 7/150
# 6/6 [==============================] - 1s 226ms/step - loss: 16.1583 - mean_absolute_error: 16.1583 - val_loss: 19.7129 - val_mean_absolute_error: 19.7129
# Epoch 8/150
# 6/6 [==============================] - 1s 224ms/step - loss: 16.0643 - mean_absolute_error: 16.0643 - val_loss: 18.7558 - val_mean_absolute_error: 18.7558
# Epoch 9/150
# 6/6 [==============================] - 1s 226ms/step - loss: 15.3773 - mean_absolute_error: 15.3773 - val_loss: 19.4857 - val_mean_absolute_error: 19.4857
# Epoch 10/150
# 6/6 [==============================] - 1s 227ms/step - loss: 15.7188 - mean_absolute_error: 15.7188 - val_loss: 18.6305 - val_mean_absolute_error: 18.6305
# Epoch 11/150
# 6/6 [==============================] - 1s 223ms/step - loss: 16.2801 - mean_absolute_error: 16.2801 - val_loss: 19.8412 - val_mean_absolute_error: 19.8412
# Epoch 12/150
# 6/6 [==============================] - 1s 222ms/step - loss: 16.1777 - mean_absolute_error: 16.1777 - val_loss: 18.2980 - val_mean_absolute_error: 18.2980
# Epoch 13/150
# 6/6 [==============================] - 1s 224ms/step - loss: 14.9527 - mean_absolute_error: 14.9527 - val_loss: 19.6884 - val_mean_absolute_error: 19.6884
# Epoch 14/150
# 6/6 [==============================] - 1s 220ms/step - loss: 15.6775 - mean_absolute_error: 15.6775 - val_loss: 19.6054 - val_mean_absolute_error: 19.6054
# Epoch 15/150
# 6/6 [==============================] - 1s 222ms/step - loss: 15.3231 - mean_absolute_error: 15.3231 - val_loss: 18.6456 - val_mean_absolute_error: 18.6456
# Epoch 16/150
# 6/6 [==============================] - 1s 221ms/step - loss: 15.4553 - mean_absolute_error: 15.4553 - val_loss: 19.8790 - val_mean_absolute_error: 19.8790
# Epoch 17/150
# 6/6 [==============================] - 1s 223ms/step - loss: 15.7189 - mean_absolute_error: 15.7189 - val_loss: 18.9811 - val_mean_absolute_error: 18.9811
# Epoch 18/150
# 6/6 [==============================] - 1s 224ms/step - loss: 15.9878 - mean_absolute_error: 15.9878 - val_loss: 19.1808 - val_mean_absolute_error: 19.1808
# Epoch 19/150
# 6/6 [==============================] - 1s 231ms/step - loss: 14.6904 - mean_absolute_error: 14.6904 - val_loss: 19.4908 - val_mean_absolute_error: 19.4908
# Epoch 20/150
# 6/6 [==============================] - 1s 228ms/step - loss: 15.4831 - mean_absolute_error: 15.4831 - val_loss: 19.0991 - val_mean_absolute_error: 19.0991
# Epoch 21/150
# 6/6 [==============================] - 1s 232ms/step - loss: 15.4755 - mean_absolute_error: 15.4755 - val_loss: 18.8648 - val_mean_absolute_error: 18.8648
# Epoch 22/150
# 6/6 [==============================] - 1s 230ms/step - loss: 15.4919 - mean_absolute_error: 15.4919 - val_loss: 19.3078 - val_mean_absolute_error: 19.3078
# Epoch 23/150
# 6/6 [==============================] - 1s 222ms/step - loss: 15.2622 - mean_absolute_error: 15.2622 - val_loss: 19.1300 - val_mean_absolute_error: 19.1300
# Epoch 24/150
# 6/6 [==============================] - 1s 230ms/step - loss: 15.1185 - mean_absolute_error: 15.1185 - val_loss: 19.2469 - val_mean_absolute_error: 19.2469
# Epoch 25/150
# 6/6 [==============================] - 1s 226ms/step - loss: 15.0603 - mean_absolute_error: 15.0603 - val_loss: 19.4710 - val_mean_absolute_error: 19.4710
# Epoch 26/150
# 6/6 [==============================] - 1s 231ms/step - loss: 15.6677 - mean_absolute_error: 15.6677 - val_loss: 18.9864 - val_mean_absolute_error: 18.9864
# Epoch 27/150
# 6/6 [==============================] - 1s 226ms/step - loss: 15.2988 - mean_absolute_error: 15.2988 - val_loss: 19.5669 - val_mean_absolute_error: 19.5669
# Epoch 28/150
# 6/6 [==============================] - 1s 229ms/step - loss: 15.6764 - mean_absolute_error: 15.6764 - val_loss: 18.8100 - val_mean_absolute_error: 18.8100
# Epoch 29/150
# 6/6 [==============================] - 1s 226ms/step - loss: 15.4783 - mean_absolute_error: 15.4783 - val_loss: 19.7656 - val_mean_absolute_error: 19.7656
# Epoch 30/150
# 6/6 [==============================] - 1s 227ms/step - loss: 16.2274 - mean_absolute_error: 16.2274 - val_loss: 18.8949 - val_mean_absolute_error: 18.8949
# Epoch 31/150
# 6/6 [==============================] - 1s 225ms/step - loss: 16.0084 - mean_absolute_error: 16.0084 - val_loss: 19.8910 - val_mean_absolute_error: 19.8910
# Epoch 32/150
# 6/6 [==============================] - 1s 225ms/step - loss: 15.4090 - mean_absolute_error: 15.4090 - val_loss: 18.6601 - val_mean_absolute_error: 18.6601
# Epoch 33/150
# 6/6 [==============================] - 1s 226ms/step - loss: 15.5481 - mean_absolute_error: 15.5481 - val_loss: 19.5205 - val_mean_absolute_error: 19.5205
# Epoch 34/150
# 6/6 [==============================] - 1s 225ms/step - loss: 15.5053 - mean_absolute_error: 15.5053 - val_loss: 18.7220 - val_mean_absolute_error: 18.7220
# Epoch 35/150
# 6/6 [==============================] - 2s 334ms/step - loss: 15.8367 - mean_absolute_error: 15.8367 - val_loss: 19.6968 - val_mean_absolute_error: 19.6968
# Epoch 36/150
# 6/6 [==============================] - 1s 230ms/step - loss: 15.5866 - mean_absolute_error: 15.5866 - val_loss: 18.9697 - val_mean_absolute_error: 18.9697
# Epoch 37/150
# 6/6 [==============================] - 1s 229ms/step - loss: 15.7456 - mean_absolute_error: 15.7456 - val_loss: 19.6495 - val_mean_absolute_error: 19.6495
# Epoch 38/150
# 6/6 [==============================] - 1s 223ms/step - loss: 14.8730 - mean_absolute_error: 14.8730 - val_loss: 18.6144 - val_mean_absolute_error: 18.6144
# Epoch 39/150
# 6/6 [==============================] - 1s 225ms/step - loss: 15.7293 - mean_absolute_error: 15.7293 - val_loss: 19.4704 - val_mean_absolute_error: 19.4704
# Epoch 40/150
# 6/6 [==============================] - 1s 230ms/step - loss: 15.2365 - mean_absolute_error: 15.2365 - val_loss: 19.1105 - val_mean_absolute_error: 19.1105
# Epoch 41/150
# 6/6 [==============================] - 1s 225ms/step - loss: 17.4280 - mean_absolute_error: 17.4280 - val_loss: 19.6170 - val_mean_absolute_error: 19.6170
# Epoch 42/150
# 6/6 [==============================] - 1s 227ms/step - loss: 17.1668 - mean_absolute_error: 17.1668 - val_loss: 20.3548 - val_mean_absolute_error: 20.3548
# Epoch 43/150
# 6/6 [==============================] - 1s 227ms/step - loss: 16.4108 - mean_absolute_error: 16.4108 - val_loss: 18.2417 - val_mean_absolute_error: 18.2417
# Epoch 44/150
# 6/6 [==============================] - 1s 227ms/step - loss: 15.4095 - mean_absolute_error: 15.4095 - val_loss: 19.7329 - val_mean_absolute_error: 19.7329
# Epoch 45/150
# 6/6 [==============================] - 1s 228ms/step - loss: 15.7374 - mean_absolute_error: 15.7374 - val_loss: 19.1259 - val_mean_absolute_error: 19.1259
# Epoch 46/150
# 6/6 [==============================] - 1s 226ms/step - loss: 15.6021 - mean_absolute_error: 15.6021 - val_loss: 19.3327 - val_mean_absolute_error: 19.3327
# Epoch 47/150
# 6/6 [==============================] - 1s 227ms/step - loss: 15.5661 - mean_absolute_error: 15.5661 - val_loss: 19.2240 - val_mean_absolute_error: 19.2240
# Epoch 48/150
# 6/6 [==============================] - 1s 227ms/step - loss: 16.0673 - mean_absolute_error: 16.0673 - val_loss: 19.4758 - val_mean_absolute_error: 19.4758
# Epoch 49/150
# 6/6 [==============================] - 1s 224ms/step - loss: 15.0914 - mean_absolute_error: 15.0914 - val_loss: 19.0373 - val_mean_absolute_error: 19.0373
# Epoch 50/150
# 6/6 [==============================] - 1s 235ms/step - loss: 15.6633 - mean_absolute_error: 15.6633 - val_loss: 19.1470 - val_mean_absolute_error: 19.1470
# Epoch 51/150
# 6/6 [==============================] - 1s 225ms/step - loss: 16.0909 - mean_absolute_error: 16.0909 - val_loss: 19.6868 - val_mean_absolute_error: 19.6868
# Epoch 52/150
# 6/6 [==============================] - 1s 227ms/step - loss: 15.7654 - mean_absolute_error: 15.7654 - val_loss: 18.9420 - val_mean_absolute_error: 18.9420
# Epoch 53/150
# 6/6 [==============================] - 1s 225ms/step - loss: 16.2299 - mean_absolute_error: 16.2299 - val_loss: 19.8598 - val_mean_absolute_error: 19.8598
# Epoch 54/150
# 6/6 [==============================] - 1s 228ms/step - loss: 15.4330 - mean_absolute_error: 15.4330 - val_loss: 18.9135 - val_mean_absolute_error: 18.9135
# Epoch 55/150
# 6/6 [==============================] - 1s 228ms/step - loss: 15.5249 - mean_absolute_error: 15.5249 - val_loss: 19.3842 - val_mean_absolute_error: 19.3842
# Epoch 56/150
# 6/6 [==============================] - 1s 228ms/step - loss: 15.2243 - mean_absolute_error: 15.2243 - val_loss: 18.9169 - val_mean_absolute_error: 18.9169
# Epoch 57/150
# 6/6 [==============================] - 1s 222ms/step - loss: 15.6008 - mean_absolute_error: 15.6008 - val_loss: 19.6867 - val_mean_absolute_error: 19.6867
# Epoch 58/150
# 6/6 [==============================] - 1s 229ms/step - loss: 15.8553 - mean_absolute_error: 15.8553 - val_loss: 19.1207 - val_mean_absolute_error: 19.1207
# Epoch 59/150
# 6/6 [==============================] - 1s 232ms/step - loss: 15.4785 - mean_absolute_error: 15.4785 - val_loss: 19.2207 - val_mean_absolute_error: 19.2207
# Epoch 60/150
# 6/6 [==============================] - 1s 226ms/step - loss: 15.3161 - mean_absolute_error: 15.3161 - val_loss: 19.4910 - val_mean_absolute_error: 19.4910
# Epoch 61/150
# 6/6 [==============================] - 1s 226ms/step - loss: 14.9867 - mean_absolute_error: 14.9867 - val_loss: 19.0803 - val_mean_absolute_error: 19.0803
# Epoch 62/150
# 6/6 [==============================] - 2s 340ms/step - loss: 15.2307 - mean_absolute_error: 15.2307 - val_loss: 19.2905 - val_mean_absolute_error: 19.2905
# Epoch 63/150
# 6/6 [==============================] - 2s 384ms/step - loss: 15.4383 - mean_absolute_error: 15.4383 - val_loss: 19.2567 - val_mean_absolute_error: 19.2567
# Epoch 64/150
# 6/6 [==============================] - 1s 229ms/step - loss: 15.4200 - mean_absolute_error: 15.4200 - val_loss: 19.6001 - val_mean_absolute_error: 19.6001
# Epoch 65/150
# 6/6 [==============================] - 1s 226ms/step - loss: 15.4462 - mean_absolute_error: 15.4462 - val_loss: 19.0607 - val_mean_absolute_error: 19.0607
# Epoch 66/150
# 6/6 [==============================] - 1s 226ms/step - loss: 16.0461 - mean_absolute_error: 16.0461 - val_loss: 19.5520 - val_mean_absolute_error: 19.5520
# Epoch 67/150
# 6/6 [==============================] - 1s 224ms/step - loss: 15.9523 - mean_absolute_error: 15.9523 - val_loss: 19.4239 - val_mean_absolute_error: 19.4239
# Epoch 68/150
# 6/6 [==============================] - 1s 221ms/step - loss: 16.4790 - mean_absolute_error: 16.4790 - val_loss: 19.9544 - val_mean_absolute_error: 19.9544
# Epoch 69/150
# 6/6 [==============================] - 1s 222ms/step - loss: 16.2666 - mean_absolute_error: 16.2666 - val_loss: 18.7956 - val_mean_absolute_error: 18.7956
# Epoch 70/150
# 6/6 [==============================] - 1s 223ms/step - loss: 15.0480 - mean_absolute_error: 15.0480 - val_loss: 19.9244 - val_mean_absolute_error: 19.9244
# Epoch 71/150
# 6/6 [==============================] - 1s 229ms/step - loss: 15.6101 - mean_absolute_error: 15.6101 - val_loss: 18.9023 - val_mean_absolute_error: 18.9023
# Epoch 72/150
# 6/6 [==============================] - 1s 227ms/step - loss: 15.3750 - mean_absolute_error: 15.3750 - val_loss: 19.8502 - val_mean_absolute_error: 19.8502
# Epoch 73/150
# 6/6 [==============================] - 1s 230ms/step - loss: 14.9390 - mean_absolute_error: 14.9390 - val_loss: 19.4829 - val_mean_absolute_error: 19.4829
# Epoch 74/150
# 6/6 [==============================] - 1s 227ms/step - loss: 15.3031 - mean_absolute_error: 15.3031 - val_loss: 19.6327 - val_mean_absolute_error: 19.6327
# Epoch 75/150
# 6/6 [==============================] - 1s 226ms/step - loss: 14.8426 - mean_absolute_error: 14.8426 - val_loss: 19.6839 - val_mean_absolute_error: 19.6839
# Epoch 76/150
# 6/6 [==============================] - 1s 227ms/step - loss: 14.9836 - mean_absolute_error: 14.9836 - val_loss: 19.8399 - val_mean_absolute_error: 19.8399
# Epoch 77/150
# 6/6 [==============================] - 1s 229ms/step - loss: 14.7218 - mean_absolute_error: 14.7218 - val_loss: 20.1405 - val_mean_absolute_error: 20.1405
# Epoch 78/150
# 6/6 [==============================] - 1s 227ms/step - loss: 14.7954 - mean_absolute_error: 14.7954 - val_loss: 20.2129 - val_mean_absolute_error: 20.2129
# Epoch 79/150
# 6/6 [==============================] - 1s 230ms/step - loss: 14.6533 - mean_absolute_error: 14.6533 - val_loss: 19.9926 - val_mean_absolute_error: 19.9926
# Epoch 80/150
# 6/6 [==============================] - 1s 227ms/step - loss: 14.8238 - mean_absolute_error: 14.8238 - val_loss: 20.2440 - val_mean_absolute_error: 20.2440
# Epoch 81/150
# 6/6 [==============================] - 1s 224ms/step - loss: 15.2542 - mean_absolute_error: 15.2542 - val_loss: 20.1961 - val_mean_absolute_error: 20.1961
# Epoch 82/150
# 6/6 [==============================] - 1s 226ms/step - loss: 14.1835 - mean_absolute_error: 14.1835 - val_loss: 19.5979 - val_mean_absolute_error: 19.5979
# Epoch 83/150
# 6/6 [==============================] - 1s 226ms/step - loss: 14.7315 - mean_absolute_error: 14.7315 - val_loss: 20.2742 - val_mean_absolute_error: 20.2742
# Epoch 84/150
# 6/6 [==============================] - 1s 227ms/step - loss: 15.2306 - mean_absolute_error: 15.2306 - val_loss: 20.8087 - val_mean_absolute_error: 20.8087
# Epoch 85/150
# 6/6 [==============================] - 1s 225ms/step - loss: 15.1108 - mean_absolute_error: 15.1108 - val_loss: 19.9639 - val_mean_absolute_error: 19.9639
# Epoch 86/150
# 6/6 [==============================] - 1s 228ms/step - loss: 15.6286 - mean_absolute_error: 15.6286 - val_loss: 21.2407 - val_mean_absolute_error: 21.2407
# Epoch 87/150
# 6/6 [==============================] - 1s 229ms/step - loss: 15.6418 - mean_absolute_error: 15.6418 - val_loss: 20.2985 - val_mean_absolute_error: 20.2985
# Epoch 88/150
# 6/6 [==============================] - 1s 228ms/step - loss: 14.4365 - mean_absolute_error: 14.4365 - val_loss: 19.3095 - val_mean_absolute_error: 19.3095
# Epoch 89/150
# 6/6 [==============================] - 1s 246ms/step - loss: 15.1635 - mean_absolute_error: 15.1635 - val_loss: 20.8097 - val_mean_absolute_error: 20.8097
# Epoch 90/150
# 6/6 [==============================] - 1s 229ms/step - loss: 14.2509 - mean_absolute_error: 14.2509 - val_loss: 19.7411 - val_mean_absolute_error: 19.7411
# Epoch 91/150
# 6/6 [==============================] - 1s 230ms/step - loss: 14.4883 - mean_absolute_error: 14.4883 - val_loss: 20.3434 - val_mean_absolute_error: 20.3434
# Epoch 92/150
# 6/6 [==============================] - 1s 229ms/step - loss: 14.9603 - mean_absolute_error: 14.9603 - val_loss: 19.7969 - val_mean_absolute_error: 19.7969
# Epoch 93/150
# 6/6 [==============================] - 1s 230ms/step - loss: 14.6631 - mean_absolute_error: 14.6631 - val_loss: 20.4805 - val_mean_absolute_error: 20.4805
# Epoch 94/150
# 6/6 [==============================] - 1s 230ms/step - loss: 16.0003 - mean_absolute_error: 16.0003 - val_loss: 20.8929 - val_mean_absolute_error: 20.8929
# Epoch 95/150
# 6/6 [==============================] - 1s 233ms/step - loss: 14.9249 - mean_absolute_error: 14.9249 - val_loss: 19.3388 - val_mean_absolute_error: 19.3388
# Epoch 96/150
# 6/6 [==============================] - 1s 231ms/step - loss: 15.2084 - mean_absolute_error: 15.2084 - val_loss: 20.2026 - val_mean_absolute_error: 20.2026
# Epoch 97/150
# 6/6 [==============================] - 1s 229ms/step - loss: 14.6464 - mean_absolute_error: 14.6464 - val_loss: 19.6269 - val_mean_absolute_error: 19.6269
# Epoch 98/150
# 6/6 [==============================] - 1s 222ms/step - loss: 14.8656 - mean_absolute_error: 14.8656 - val_loss: 20.4056 - val_mean_absolute_error: 20.4056
# Epoch 99/150
# 6/6 [==============================] - 1s 227ms/step - loss: 14.2421 - mean_absolute_error: 14.2421 - val_loss: 19.6569 - val_mean_absolute_error: 19.6569
# Epoch 100/150
# 6/6 [==============================] - 1s 226ms/step - loss: 14.6310 - mean_absolute_error: 14.6310 - val_loss: 20.4221 - val_mean_absolute_error: 20.4221
# Epoch 101/150
# 6/6 [==============================] - 1s 221ms/step - loss: 14.6870 - mean_absolute_error: 14.6870 - val_loss: 19.4660 - val_mean_absolute_error: 19.4660
# Epoch 102/150
# 6/6 [==============================] - 1s 230ms/step - loss: 14.7626 - mean_absolute_error: 14.7626 - val_loss: 20.5095 - val_mean_absolute_error: 20.5095
# Epoch 103/150
# 6/6 [==============================] - 1s 220ms/step - loss: 14.0708 - mean_absolute_error: 14.0708 - val_loss: 20.2253 - val_mean_absolute_error: 20.2253
# Epoch 104/150
# 6/6 [==============================] - 1s 223ms/step - loss: 14.0010 - mean_absolute_error: 14.0010 - val_loss: 20.3617 - val_mean_absolute_error: 20.3617
# Epoch 105/150
# 6/6 [==============================] - 2s 354ms/step - loss: 14.5196 - mean_absolute_error: 14.5196 - val_loss: 20.4138 - val_mean_absolute_error: 20.4138
# Epoch 106/150
# 6/6 [==============================] - 2s 225ms/step - loss: 14.4611 - mean_absolute_error: 14.4611 - val_loss: 20.0431 - val_mean_absolute_error: 20.0431
# Epoch 107/150
# 6/6 [==============================] - 1s 226ms/step - loss: 14.5585 - mean_absolute_error: 14.5585 - val_loss: 20.3800 - val_mean_absolute_error: 20.3800
# Epoch 108/150
# 6/6 [==============================] - 1s 228ms/step - loss: 14.0882 - mean_absolute_error: 14.0882 - val_loss: 19.8754 - val_mean_absolute_error: 19.8754
# Epoch 109/150
# 6/6 [==============================] - 1s 224ms/step - loss: 14.7309 - mean_absolute_error: 14.7309 - val_loss: 20.5576 - val_mean_absolute_error: 20.5576
# Epoch 110/150
# 6/6 [==============================] - 1s 224ms/step - loss: 14.1146 - mean_absolute_error: 14.1146 - val_loss: 20.4197 - val_mean_absolute_error: 20.4197
# Epoch 111/150
# 6/6 [==============================] - 1s 225ms/step - loss: 14.2620 - mean_absolute_error: 14.2620 - val_loss: 20.4835 - val_mean_absolute_error: 20.4835
# Epoch 112/150
# 6/6 [==============================] - 1s 225ms/step - loss: 14.5079 - mean_absolute_error: 14.5079 - val_loss: 20.2809 - val_mean_absolute_error: 20.2809
# Epoch 113/150
# 6/6 [==============================] - 1s 225ms/step - loss: 14.3109 - mean_absolute_error: 14.3109 - val_loss: 20.1403 - val_mean_absolute_error: 20.1403
# Epoch 114/150
# 6/6 [==============================] - 1s 228ms/step - loss: 14.8496 - mean_absolute_error: 14.8496 - val_loss: 20.1701 - val_mean_absolute_error: 20.1701
# Epoch 115/150
# 6/6 [==============================] - 1s 228ms/step - loss: 14.5317 - mean_absolute_error: 14.5317 - val_loss: 20.2255 - val_mean_absolute_error: 20.2255
# Epoch 116/150
# 6/6 [==============================] - 1s 229ms/step - loss: 14.2284 - mean_absolute_error: 14.2284 - val_loss: 20.0142 - val_mean_absolute_error: 20.0142
# Epoch 117/150
# 6/6 [==============================] - 1s 227ms/step - loss: 14.0492 - mean_absolute_error: 14.0492 - val_loss: 20.3918 - val_mean_absolute_error: 20.3918
# Epoch 118/150
# 6/6 [==============================] - 1s 224ms/step - loss: 14.6180 - mean_absolute_error: 14.6180 - val_loss: 20.6096 - val_mean_absolute_error: 20.6096
# Epoch 119/150
# 6/6 [==============================] - 1s 229ms/step - loss: 14.4151 - mean_absolute_error: 14.4151 - val_loss: 20.6527 - val_mean_absolute_error: 20.6527
# Epoch 120/150
# 6/6 [==============================] - 1s 227ms/step - loss: 14.0551 - mean_absolute_error: 14.0551 - val_loss: 20.5987 - val_mean_absolute_error: 20.5987
# Epoch 121/150
# 6/6 [==============================] - 1s 226ms/step - loss: 13.9487 - mean_absolute_error: 13.9487 - val_loss: 20.4326 - val_mean_absolute_error: 20.4326
# Epoch 122/150
# 6/6 [==============================] - 1s 225ms/step - loss: 14.5927 - mean_absolute_error: 14.5927 - val_loss: 20.7582 - val_mean_absolute_error: 20.7582
# Epoch 123/150
# 6/6 [==============================] - 1s 227ms/step - loss: 14.3755 - mean_absolute_error: 14.3755 - val_loss: 20.8135 - val_mean_absolute_error: 20.8135
# Epoch 124/150
# 6/6 [==============================] - 1s 231ms/step - loss: 14.6432 - mean_absolute_error: 14.6432 - val_loss: 20.5140 - val_mean_absolute_error: 20.5140
# Epoch 125/150
# 6/6 [==============================] - 1s 226ms/step - loss: 14.6694 - mean_absolute_error: 14.6694 - val_loss: 20.5818 - val_mean_absolute_error: 20.5818
# Epoch 126/150
# 6/6 [==============================] - 1s 230ms/step - loss: 15.2449 - mean_absolute_error: 15.2449 - val_loss: 20.6648 - val_mean_absolute_error: 20.6648
# Epoch 127/150
# 6/6 [==============================] - 1s 226ms/step - loss: 14.4206 - mean_absolute_error: 14.4206 - val_loss: 20.4430 - val_mean_absolute_error: 20.4430
# Epoch 128/150
# 6/6 [==============================] - 1s 225ms/step - loss: 14.7658 - mean_absolute_error: 14.7658 - val_loss: 20.6499 - val_mean_absolute_error: 20.6499
# Epoch 129/150
# 6/6 [==============================] - 1s 230ms/step - loss: 14.3007 - mean_absolute_error: 14.3007 - val_loss: 19.5939 - val_mean_absolute_error: 19.5939
# Epoch 130/150
# 6/6 [==============================] - 1s 225ms/step - loss: 14.3373 - mean_absolute_error: 14.3373 - val_loss: 21.1608 - val_mean_absolute_error: 21.1608
# Epoch 131/150
# 6/6 [==============================] - 1s 229ms/step - loss: 14.2231 - mean_absolute_error: 14.2231 - val_loss: 19.7767 - val_mean_absolute_error: 19.7767
# Epoch 132/150
# 6/6 [==============================] - 1s 228ms/step - loss: 14.4442 - mean_absolute_error: 14.4442 - val_loss: 20.6209 - val_mean_absolute_error: 20.6209
# Epoch 133/150
# 6/6 [==============================] - 1s 224ms/step - loss: 14.8208 - mean_absolute_error: 14.8208 - val_loss: 20.3735 - val_mean_absolute_error: 20.3735
# Epoch 134/150
# 6/6 [==============================] - 1s 229ms/step - loss: 14.2209 - mean_absolute_error: 14.2209 - val_loss: 20.3643 - val_mean_absolute_error: 20.3643
# Epoch 135/150
# 6/6 [==============================] - 1s 229ms/step - loss: 14.7847 - mean_absolute_error: 14.7847 - val_loss: 20.6598 - val_mean_absolute_error: 20.6598
# Epoch 136/150
# 6/6 [==============================] - 1s 228ms/step - loss: 13.9015 - mean_absolute_error: 13.9015 - val_loss: 19.7159 - val_mean_absolute_error: 19.7159
# Epoch 137/150
# 6/6 [==============================] - 1s 229ms/step - loss: 14.3704 - mean_absolute_error: 14.3704 - val_loss: 20.7409 - val_mean_absolute_error: 20.7409
# Epoch 138/150
# 6/6 [==============================] - 1s 231ms/step - loss: 14.8789 - mean_absolute_error: 14.8789 - val_loss: 19.5761 - val_mean_absolute_error: 19.5761
# Epoch 139/150
# 6/6 [==============================] - 1s 225ms/step - loss: 15.0141 - mean_absolute_error: 15.0141 - val_loss: 20.0746 - val_mean_absolute_error: 20.0746
# Epoch 140/150
# 6/6 [==============================] - 1s 227ms/step - loss: 15.3101 - mean_absolute_error: 15.3101 - val_loss: 20.7430 - val_mean_absolute_error: 20.7430
# Epoch 141/150
# 6/6 [==============================] - 1s 229ms/step - loss: 14.5514 - mean_absolute_error: 14.5514 - val_loss: 19.4437 - val_mean_absolute_error: 19.4437
# Epoch 142/150
# 6/6 [==============================] - 1s 229ms/step - loss: 13.5841 - mean_absolute_error: 13.5841 - val_loss: 20.7535 - val_mean_absolute_error: 20.7535
# Epoch 143/150
# 6/6 [==============================] - 1s 228ms/step - loss: 14.6214 - mean_absolute_error: 14.6214 - val_loss: 19.8094 - val_mean_absolute_error: 19.8094
# Epoch 144/150
# 6/6 [==============================] - 1s 231ms/step - loss: 14.6772 - mean_absolute_error: 14.6772 - val_loss: 20.2245 - val_mean_absolute_error: 20.2245
# Epoch 145/150
# 6/6 [==============================] - 1s 228ms/step - loss: 14.3447 - mean_absolute_error: 14.3447 - val_loss: 20.2886 - val_mean_absolute_error: 20.2886
# Epoch 146/150
# 6/6 [==============================] - 1s 228ms/step - loss: 13.8943 - mean_absolute_error: 13.8943 - val_loss: 19.3958 - val_mean_absolute_error: 19.3958
# Epoch 147/150
# 6/6 [==============================] - 1s 230ms/step - loss: 13.6866 - mean_absolute_error: 13.6866 - val_loss: 20.2936 - val_mean_absolute_error: 20.2936
# Epoch 148/150
# 6/6 [==============================] - 1s 228ms/step - loss: 14.1039 - mean_absolute_error: 14.1039 - val_loss: 20.0752 - val_mean_absolute_error: 20.0752
# Epoch 149/150
# 6/6 [==============================] - 1s 228ms/step - loss: 13.9157 - mean_absolute_error: 13.9157 - val_loss: 20.0787 - val_mean_absolute_error: 20.0787
# Epoch 150/150
# 6/6 [==============================] - 1s 232ms/step - loss: 13.8095 - mean_absolute_error: 13.8095 - val_loss: 20.6310 - val_mean_absolute_error: 20.6310

# %%
import os

import tensorflow as tf
from tensorflow import keras

print(tf.version.VERSION)
model3.save('/content/drive/MyDrive/Grad2Models/yasNMR')
# Out:
# 2.8.2
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Grad2Models/yasNMR/assets

# %%
new_model = tf.keras.models.load_model('/content/drive/MyDrive/Grad2Models/yasNMR')

# Check its architecture
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 195, 256)          1024
#
#  conv1d_1 (Conv1D)           (None, 193, 256)          196864
#
#  dropout (Dropout)           (None, 193, 256)          0
#
#  max_pooling1d (MaxPooling1D  (None, 96, 256)          0
#  )
#
#  conv1d_2 (Conv1D)           (None, 94, 128)           98432
#
#  max_pooling1d_1 (MaxPooling  (None, 47, 128)          0
#  1D)
#
#  dropout_1 (Dropout)         (None, 47, 128)           0
#
#  conv1d_3 (Conv1D)           (None, 45, 64)            24640
#
#  max_pooling1d_2 (MaxPooling  (None, 22, 64)           0
#  1D)
#
#  dropout_2 (Dropout)         (None, 22, 64)            0
#
#  flatten (Flatten)           (None, 1408)              0
#
#  dense (Dense)               (None, 16)                22544
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 343,521
# Trainable params: 343,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
print(history.history.keys())

plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
prediction=new_model.predict(X_test)


yout=y_test.to_numpy()    
counter=0
counter2=0
counter3=0
yout = yout. astype(int)
total=0
for i in range (prediction.shape[0]):
  if prediction[i]%1>=0.5:
    prediction[i]=int(prediction[i])+1
  else :
     prediction[i]=int(prediction[i])  

for i in range (prediction.shape[0]):
  if prediction[i]>yout[i]:
    total=total+prediction[i]-yout[i]
  else:
    total=total+yout[i]-prediction[i]

print("Hata Payı = %",total/100)
# Out:
# Hata Payı = % [43.69]
