# %%
import pandas as pd
import numpy as np

urineDS=pd.read_csv("/content/drive/MyDrive/Grad2/lastUrine.csv")
urineDS=urineDS.iloc[:,1:]

from sklearn.preprocessing import StandardScaler


urineOutput=urineDS.iloc[2:,1:2]
urineInput=urineDS.iloc[2:,4:]

data = urineInput
scaler = StandardScaler()
scaler.fit(data)
urineInput=scaler.transform(data)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(urineInput, urineOutput, test_size=0.33, random_state=0)

# %%
X_train=X_train.astype(np.float64)
X_test=X_test.astype(np.float64)
y_train=y_train.astype(np.float64)
y_test=y_test.astype(np.float64)

X_train=X_train.astype(np.int64)
y_train=y_train.astype(np.int64)
X_train=X_train.astype(np.float64)
y_train=y_train.astype(np.float64)
print(y_train)
# Out:
#      Unnamed: 1
# 231        46.0
# 20         52.0
# 169        25.0
# 254        50.0
# 126        73.0
# ..          ...
# 253        30.0
# 194        60.0
# 119        61.0
# 49         61.0
# 174        62.0
#
# [201 rows x 1 columns]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Flatten,concatenate

from tensorflow.keras.optimizers import Adam
from keras.layers import Dropout
import keras
from matplotlib import pyplot as plt

model = Sequential()
model.add(Conv1D(256, 3, activation='relu', input_shape=(8, 1)))
model.add(Conv1D(256, 3, activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling1D(2))
model.add(Conv1D(128, 2, activation='relu'))
model.add(MaxPooling1D(1))
model.add(Dropout(0.25))
model.add(Conv1D(64, 1, activation='relu'))
model.add(MaxPooling1D(1))
model.add(Dropout(0.5))
model.add(Flatten())
x1=model.output

model2 = Sequential()
model2.add(Conv1D(256, 3, activation='relu', input_shape=(324, 1)))
model2.add(Conv1D(256, 3, activation='relu'))
model2.add(Dropout(0.25))
model2.add(MaxPooling1D(2))
model2.add(Conv1D(128, 3, activation='relu'))
model2.add(MaxPooling1D(2))
model2.add(Dropout(0.25))
model2.add(Conv1D(64, 3, activation='relu'))
model2.add(MaxPooling1D(2))
model2.add(Dropout(0.5))
model2.add(Flatten())
x2=model2.output

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os
import keras
from keras.models import Sequential, Model
from keras.layers import GlobalAveragePooling2D, Dense, Input, Dropout, concatenate
from keras.applications.vgg16 import VGG16
from sklearn.model_selection import train_test_split

from math import ceil
import datetime

# %%
x = concatenate([ x2,x1])
#x = Sequential()(x)
x = Dense(16, activation='relu')(x) 
x = Dropout(0.2)(x)
predictions = Dense(1, activation='relu')(x)


model4 = Model(inputs=[ model2.input,model.input], outputs=predictions) # Inputs go into 3 different layers
model4.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_absolute_error'])

# %%
history =model4.fit((X_train[:,197:521],X_train[:,521:529]),y_train, batch_size=32, epochs=150, validation_split=0.1)
# Out:
# Epoch 1/150
# 6/6 [==============================] - 4s 409ms/step - loss: 40.3706 - mean_absolute_error: 40.3706 - val_loss: 23.5981 - val_mean_absolute_error: 23.5981
# Epoch 2/150
# 6/6 [==============================] - 2s 353ms/step - loss: 20.8974 - mean_absolute_error: 20.8974 - val_loss: 18.4220 - val_mean_absolute_error: 18.4220
# Epoch 3/150
# 6/6 [==============================] - 2s 360ms/step - loss: 20.1620 - mean_absolute_error: 20.1620 - val_loss: 22.2961 - val_mean_absolute_error: 22.2961
# Epoch 4/150
# 6/6 [==============================] - 2s 355ms/step - loss: 19.5011 - mean_absolute_error: 19.5011 - val_loss: 19.7995 - val_mean_absolute_error: 19.7995
# Epoch 5/150
# 6/6 [==============================] - 2s 356ms/step - loss: 17.0527 - mean_absolute_error: 17.0527 - val_loss: 18.2176 - val_mean_absolute_error: 18.2176
# Epoch 6/150
# 6/6 [==============================] - 2s 358ms/step - loss: 18.1699 - mean_absolute_error: 18.1699 - val_loss: 19.3967 - val_mean_absolute_error: 19.3967
# Epoch 7/150
# 6/6 [==============================] - 2s 359ms/step - loss: 14.8129 - mean_absolute_error: 14.8129 - val_loss: 18.6298 - val_mean_absolute_error: 18.6298
# Epoch 8/150
# 6/6 [==============================] - 2s 357ms/step - loss: 14.7850 - mean_absolute_error: 14.7850 - val_loss: 17.0868 - val_mean_absolute_error: 17.0868
# Epoch 9/150
# 6/6 [==============================] - 2s 355ms/step - loss: 14.0964 - mean_absolute_error: 14.0964 - val_loss: 17.8036 - val_mean_absolute_error: 17.8036
# Epoch 10/150
# 6/6 [==============================] - 2s 355ms/step - loss: 12.4928 - mean_absolute_error: 12.4928 - val_loss: 16.5309 - val_mean_absolute_error: 16.5309
# Epoch 11/150
# 6/6 [==============================] - 2s 349ms/step - loss: 13.2068 - mean_absolute_error: 13.2068 - val_loss: 16.8794 - val_mean_absolute_error: 16.8794
# Epoch 12/150
# 6/6 [==============================] - 2s 350ms/step - loss: 13.0750 - mean_absolute_error: 13.0750 - val_loss: 15.5372 - val_mean_absolute_error: 15.5372
# Epoch 13/150
# 6/6 [==============================] - 2s 353ms/step - loss: 12.0862 - mean_absolute_error: 12.0862 - val_loss: 15.0233 - val_mean_absolute_error: 15.0233
# Epoch 14/150
# 6/6 [==============================] - 2s 357ms/step - loss: 12.1505 - mean_absolute_error: 12.1505 - val_loss: 14.7399 - val_mean_absolute_error: 14.7399
# Epoch 15/150
# 6/6 [==============================] - 2s 356ms/step - loss: 11.7194 - mean_absolute_error: 11.7194 - val_loss: 15.2681 - val_mean_absolute_error: 15.2681
# Epoch 16/150
# 6/6 [==============================] - 2s 356ms/step - loss: 10.6633 - mean_absolute_error: 10.6633 - val_loss: 13.2914 - val_mean_absolute_error: 13.2914
# Epoch 17/150
# 6/6 [==============================] - 2s 360ms/step - loss: 10.9025 - mean_absolute_error: 10.9025 - val_loss: 16.4236 - val_mean_absolute_error: 16.4236
# Epoch 18/150
# 6/6 [==============================] - 2s 357ms/step - loss: 10.9851 - mean_absolute_error: 10.9851 - val_loss: 14.6706 - val_mean_absolute_error: 14.6706
# Epoch 19/150
# 6/6 [==============================] - 2s 354ms/step - loss: 11.1467 - mean_absolute_error: 11.1467 - val_loss: 15.1558 - val_mean_absolute_error: 15.1558
# Epoch 20/150
# 6/6 [==============================] - 2s 356ms/step - loss: 10.2393 - mean_absolute_error: 10.2393 - val_loss: 14.8998 - val_mean_absolute_error: 14.8998
# Epoch 21/150
# 6/6 [==============================] - 2s 354ms/step - loss: 10.1081 - mean_absolute_error: 10.1081 - val_loss: 15.1914 - val_mean_absolute_error: 15.1914
# Epoch 22/150
# 6/6 [==============================] - 2s 353ms/step - loss: 11.2748 - mean_absolute_error: 11.2748 - val_loss: 12.9302 - val_mean_absolute_error: 12.9302
# Epoch 23/150
# 6/6 [==============================] - 2s 353ms/step - loss: 10.8877 - mean_absolute_error: 10.8877 - val_loss: 15.3644 - val_mean_absolute_error: 15.3644
# Epoch 24/150
# 6/6 [==============================] - 2s 352ms/step - loss: 10.6469 - mean_absolute_error: 10.6469 - val_loss: 13.6809 - val_mean_absolute_error: 13.6809
# Epoch 25/150
# 6/6 [==============================] - 2s 354ms/step - loss: 9.3350 - mean_absolute_error: 9.3350 - val_loss: 15.3486 - val_mean_absolute_error: 15.3486
# Epoch 26/150
# 6/6 [==============================] - 2s 354ms/step - loss: 10.1640 - mean_absolute_error: 10.1640 - val_loss: 13.3126 - val_mean_absolute_error: 13.3126
# Epoch 27/150
# 6/6 [==============================] - 2s 358ms/step - loss: 10.8274 - mean_absolute_error: 10.8274 - val_loss: 14.6288 - val_mean_absolute_error: 14.6288
# Epoch 28/150
# 6/6 [==============================] - 2s 363ms/step - loss: 9.1878 - mean_absolute_error: 9.1878 - val_loss: 15.5291 - val_mean_absolute_error: 15.5291
# Epoch 29/150
# 6/6 [==============================] - 2s 356ms/step - loss: 10.3593 - mean_absolute_error: 10.3593 - val_loss: 16.2093 - val_mean_absolute_error: 16.2093
# Epoch 30/150
# 6/6 [==============================] - 2s 353ms/step - loss: 10.4279 - mean_absolute_error: 10.4279 - val_loss: 16.0472 - val_mean_absolute_error: 16.0472
# Epoch 31/150
# 6/6 [==============================] - 2s 356ms/step - loss: 10.5135 - mean_absolute_error: 10.5135 - val_loss: 14.2635 - val_mean_absolute_error: 14.2635
# Epoch 32/150
# 6/6 [==============================] - 2s 353ms/step - loss: 9.8551 - mean_absolute_error: 9.8551 - val_loss: 16.3048 - val_mean_absolute_error: 16.3048
# Epoch 33/150
# 6/6 [==============================] - 2s 355ms/step - loss: 10.3405 - mean_absolute_error: 10.3405 - val_loss: 15.2870 - val_mean_absolute_error: 15.2870
# Epoch 34/150
# 6/6 [==============================] - 2s 353ms/step - loss: 10.1932 - mean_absolute_error: 10.1932 - val_loss: 15.9711 - val_mean_absolute_error: 15.9711
# Epoch 35/150
# 6/6 [==============================] - 2s 353ms/step - loss: 10.4241 - mean_absolute_error: 10.4241 - val_loss: 17.3016 - val_mean_absolute_error: 17.3016
# Epoch 36/150
# 6/6 [==============================] - 2s 356ms/step - loss: 10.8285 - mean_absolute_error: 10.8285 - val_loss: 15.6728 - val_mean_absolute_error: 15.6728
# Epoch 37/150
# 6/6 [==============================] - 2s 356ms/step - loss: 10.0532 - mean_absolute_error: 10.0532 - val_loss: 15.9034 - val_mean_absolute_error: 15.9034
# Epoch 38/150
# 6/6 [==============================] - 2s 359ms/step - loss: 9.1950 - mean_absolute_error: 9.1950 - val_loss: 15.6540 - val_mean_absolute_error: 15.6540
# Epoch 39/150
# 6/6 [==============================] - 2s 355ms/step - loss: 9.3454 - mean_absolute_error: 9.3454 - val_loss: 15.8723 - val_mean_absolute_error: 15.8723
# Epoch 40/150
# 6/6 [==============================] - 2s 355ms/step - loss: 8.9049 - mean_absolute_error: 8.9049 - val_loss: 15.8755 - val_mean_absolute_error: 15.8755
# Epoch 41/150
# 6/6 [==============================] - 2s 354ms/step - loss: 10.1056 - mean_absolute_error: 10.1056 - val_loss: 16.5482 - val_mean_absolute_error: 16.5482
# Epoch 42/150
# 6/6 [==============================] - 2s 354ms/step - loss: 10.2439 - mean_absolute_error: 10.2439 - val_loss: 15.6063 - val_mean_absolute_error: 15.6063
# Epoch 43/150
# 6/6 [==============================] - 2s 358ms/step - loss: 9.7331 - mean_absolute_error: 9.7331 - val_loss: 17.1558 - val_mean_absolute_error: 17.1558
# Epoch 44/150
# 6/6 [==============================] - 2s 353ms/step - loss: 10.2474 - mean_absolute_error: 10.2474 - val_loss: 15.7264 - val_mean_absolute_error: 15.7264
# Epoch 45/150
# 6/6 [==============================] - 2s 352ms/step - loss: 10.3466 - mean_absolute_error: 10.3466 - val_loss: 16.4319 - val_mean_absolute_error: 16.4319
# Epoch 46/150
# 6/6 [==============================] - 2s 351ms/step - loss: 10.5768 - mean_absolute_error: 10.5768 - val_loss: 15.0182 - val_mean_absolute_error: 15.0182
# Epoch 47/150
# 6/6 [==============================] - 2s 353ms/step - loss: 10.3917 - mean_absolute_error: 10.3917 - val_loss: 14.7908 - val_mean_absolute_error: 14.7908
# Epoch 48/150
# 6/6 [==============================] - 2s 353ms/step - loss: 8.8671 - mean_absolute_error: 8.8671 - val_loss: 14.3434 - val_mean_absolute_error: 14.3434
# Epoch 49/150
# 6/6 [==============================] - 2s 354ms/step - loss: 10.4196 - mean_absolute_error: 10.4196 - val_loss: 18.9376 - val_mean_absolute_error: 18.9376
# Epoch 50/150
# 6/6 [==============================] - 2s 359ms/step - loss: 10.3972 - mean_absolute_error: 10.3972 - val_loss: 14.2097 - val_mean_absolute_error: 14.2097
# Epoch 51/150
# 6/6 [==============================] - 2s 353ms/step - loss: 10.6853 - mean_absolute_error: 10.6853 - val_loss: 14.9258 - val_mean_absolute_error: 14.9258
# Epoch 52/150
# 6/6 [==============================] - 2s 358ms/step - loss: 10.0688 - mean_absolute_error: 10.0688 - val_loss: 14.3823 - val_mean_absolute_error: 14.3823
# Epoch 53/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.2376 - mean_absolute_error: 9.2376 - val_loss: 14.8681 - val_mean_absolute_error: 14.8681
# Epoch 54/150
# 6/6 [==============================] - 2s 355ms/step - loss: 9.8529 - mean_absolute_error: 9.8529 - val_loss: 14.9923 - val_mean_absolute_error: 14.9923
# Epoch 55/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.9177 - mean_absolute_error: 9.9177 - val_loss: 16.0087 - val_mean_absolute_error: 16.0087
# Epoch 56/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.8630 - mean_absolute_error: 9.8630 - val_loss: 13.6981 - val_mean_absolute_error: 13.6981
# Epoch 57/150
# 6/6 [==============================] - 2s 360ms/step - loss: 9.1580 - mean_absolute_error: 9.1580 - val_loss: 15.2587 - val_mean_absolute_error: 15.2587
# Epoch 58/150
# 6/6 [==============================] - 2s 357ms/step - loss: 9.8250 - mean_absolute_error: 9.8250 - val_loss: 14.6590 - val_mean_absolute_error: 14.6590
# Epoch 59/150
# 6/6 [==============================] - 2s 358ms/step - loss: 9.1078 - mean_absolute_error: 9.1078 - val_loss: 16.6620 - val_mean_absolute_error: 16.6620
# Epoch 60/150
# 6/6 [==============================] - 2s 354ms/step - loss: 9.0566 - mean_absolute_error: 9.0566 - val_loss: 14.7406 - val_mean_absolute_error: 14.7406
# Epoch 61/150
# 6/6 [==============================] - 2s 357ms/step - loss: 9.5115 - mean_absolute_error: 9.5115 - val_loss: 16.5696 - val_mean_absolute_error: 16.5696
# Epoch 62/150
# 6/6 [==============================] - 2s 359ms/step - loss: 9.6810 - mean_absolute_error: 9.6810 - val_loss: 14.2209 - val_mean_absolute_error: 14.2209
# Epoch 63/150
# 6/6 [==============================] - 2s 358ms/step - loss: 10.0372 - mean_absolute_error: 10.0372 - val_loss: 16.4223 - val_mean_absolute_error: 16.4223
# Epoch 64/150
# 6/6 [==============================] - 2s 355ms/step - loss: 10.1491 - mean_absolute_error: 10.1491 - val_loss: 14.4795 - val_mean_absolute_error: 14.4795
# Epoch 65/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.9067 - mean_absolute_error: 9.9067 - val_loss: 18.8331 - val_mean_absolute_error: 18.8331
# Epoch 66/150
# 6/6 [==============================] - 2s 354ms/step - loss: 10.5383 - mean_absolute_error: 10.5383 - val_loss: 14.1630 - val_mean_absolute_error: 14.1630
# Epoch 67/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.0388 - mean_absolute_error: 9.0388 - val_loss: 16.3677 - val_mean_absolute_error: 16.3677
# Epoch 68/150
# 6/6 [==============================] - 2s 352ms/step - loss: 9.4298 - mean_absolute_error: 9.4298 - val_loss: 14.7121 - val_mean_absolute_error: 14.7121
# Epoch 69/150
# 6/6 [==============================] - 2s 355ms/step - loss: 9.5977 - mean_absolute_error: 9.5977 - val_loss: 16.8606 - val_mean_absolute_error: 16.8606
# Epoch 70/150
# 6/6 [==============================] - 2s 354ms/step - loss: 9.0356 - mean_absolute_error: 9.0356 - val_loss: 15.7023 - val_mean_absolute_error: 15.7023
# Epoch 71/150
# 6/6 [==============================] - 2s 357ms/step - loss: 9.1669 - mean_absolute_error: 9.1669 - val_loss: 17.0178 - val_mean_absolute_error: 17.0178
# Epoch 72/150
# 6/6 [==============================] - 2s 362ms/step - loss: 9.1319 - mean_absolute_error: 9.1319 - val_loss: 14.6024 - val_mean_absolute_error: 14.6024
# Epoch 73/150
# 6/6 [==============================] - 2s 357ms/step - loss: 10.3255 - mean_absolute_error: 10.3255 - val_loss: 16.3276 - val_mean_absolute_error: 16.3276
# Epoch 74/150
# 6/6 [==============================] - 2s 355ms/step - loss: 9.7500 - mean_absolute_error: 9.7500 - val_loss: 14.9090 - val_mean_absolute_error: 14.9090
# Epoch 75/150
# 6/6 [==============================] - 2s 354ms/step - loss: 10.3240 - mean_absolute_error: 10.3240 - val_loss: 16.5832 - val_mean_absolute_error: 16.5832
# Epoch 76/150
# 6/6 [==============================] - 2s 359ms/step - loss: 9.9242 - mean_absolute_error: 9.9242 - val_loss: 16.2385 - val_mean_absolute_error: 16.2385
# Epoch 77/150
# 6/6 [==============================] - 2s 354ms/step - loss: 9.5017 - mean_absolute_error: 9.5017 - val_loss: 13.6121 - val_mean_absolute_error: 13.6121
# Epoch 78/150
# 6/6 [==============================] - 2s 354ms/step - loss: 9.5655 - mean_absolute_error: 9.5655 - val_loss: 16.1950 - val_mean_absolute_error: 16.1950
# Epoch 79/150
# 6/6 [==============================] - 2s 351ms/step - loss: 9.3709 - mean_absolute_error: 9.3709 - val_loss: 14.4441 - val_mean_absolute_error: 14.4441
# Epoch 80/150
# 6/6 [==============================] - 2s 355ms/step - loss: 9.4215 - mean_absolute_error: 9.4215 - val_loss: 17.5060 - val_mean_absolute_error: 17.5060
# Epoch 81/150
# 6/6 [==============================] - 2s 358ms/step - loss: 10.2103 - mean_absolute_error: 10.2103 - val_loss: 15.1626 - val_mean_absolute_error: 15.1626
# Epoch 82/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.4143 - mean_absolute_error: 9.4143 - val_loss: 17.3469 - val_mean_absolute_error: 17.3469
# Epoch 83/150
# 6/6 [==============================] - 2s 357ms/step - loss: 8.1344 - mean_absolute_error: 8.1344 - val_loss: 16.9734 - val_mean_absolute_error: 16.9734
# Epoch 84/150
# 6/6 [==============================] - 2s 361ms/step - loss: 9.5554 - mean_absolute_error: 9.5554 - val_loss: 16.2736 - val_mean_absolute_error: 16.2736
# Epoch 85/150
# 6/6 [==============================] - 2s 359ms/step - loss: 9.1142 - mean_absolute_error: 9.1142 - val_loss: 15.5858 - val_mean_absolute_error: 15.5858
# Epoch 86/150
# 6/6 [==============================] - 2s 362ms/step - loss: 9.3629 - mean_absolute_error: 9.3629 - val_loss: 16.7028 - val_mean_absolute_error: 16.7028
# Epoch 87/150
# 6/6 [==============================] - 2s 357ms/step - loss: 8.7779 - mean_absolute_error: 8.7779 - val_loss: 13.6290 - val_mean_absolute_error: 13.6290
# Epoch 88/150
# 6/6 [==============================] - 2s 353ms/step - loss: 9.6226 - mean_absolute_error: 9.6226 - val_loss: 16.7874 - val_mean_absolute_error: 16.7874
# Epoch 89/150
# 6/6 [==============================] - 2s 353ms/step - loss: 8.6808 - mean_absolute_error: 8.6808 - val_loss: 15.7801 - val_mean_absolute_error: 15.7801
# Epoch 90/150
# 6/6 [==============================] - 2s 360ms/step - loss: 9.2464 - mean_absolute_error: 9.2464 - val_loss: 15.7748 - val_mean_absolute_error: 15.7748
# Epoch 91/150
# 6/6 [==============================] - 2s 355ms/step - loss: 10.0734 - mean_absolute_error: 10.0734 - val_loss: 14.7928 - val_mean_absolute_error: 14.7928
# Epoch 92/150
# 6/6 [==============================] - 2s 356ms/step - loss: 8.9086 - mean_absolute_error: 8.9086 - val_loss: 14.4506 - val_mean_absolute_error: 14.4506
# Epoch 93/150
# 6/6 [==============================] - 2s 358ms/step - loss: 8.9079 - mean_absolute_error: 8.9079 - val_loss: 15.8651 - val_mean_absolute_error: 15.8651
# Epoch 94/150
# 6/6 [==============================] - 2s 360ms/step - loss: 8.1628 - mean_absolute_error: 8.1628 - val_loss: 14.5464 - val_mean_absolute_error: 14.5464
# Epoch 95/150
# 6/6 [==============================] - 2s 357ms/step - loss: 9.7554 - mean_absolute_error: 9.7554 - val_loss: 16.1011 - val_mean_absolute_error: 16.1011
# Epoch 96/150
# 6/6 [==============================] - 2s 354ms/step - loss: 9.1575 - mean_absolute_error: 9.1575 - val_loss: 13.7695 - val_mean_absolute_error: 13.7695
# Epoch 97/150
# 6/6 [==============================] - 2s 359ms/step - loss: 9.2986 - mean_absolute_error: 9.2986 - val_loss: 16.1894 - val_mean_absolute_error: 16.1894
# Epoch 98/150
# 6/6 [==============================] - 2s 356ms/step - loss: 10.1105 - mean_absolute_error: 10.1105 - val_loss: 14.6963 - val_mean_absolute_error: 14.6963
# Epoch 99/150
# 6/6 [==============================] - 2s 355ms/step - loss: 9.2685 - mean_absolute_error: 9.2685 - val_loss: 15.4000 - val_mean_absolute_error: 15.4000
# Epoch 100/150
# 6/6 [==============================] - 2s 360ms/step - loss: 9.7151 - mean_absolute_error: 9.7151 - val_loss: 15.9605 - val_mean_absolute_error: 15.9605
# Epoch 101/150
# 6/6 [==============================] - 2s 358ms/step - loss: 10.1853 - mean_absolute_error: 10.1853 - val_loss: 16.1970 - val_mean_absolute_error: 16.1970
# Epoch 102/150
# 6/6 [==============================] - 2s 354ms/step - loss: 9.2096 - mean_absolute_error: 9.2096 - val_loss: 17.2005 - val_mean_absolute_error: 17.2005
# Epoch 103/150
# 6/6 [==============================] - 2s 357ms/step - loss: 8.7431 - mean_absolute_error: 8.7431 - val_loss: 14.6036 - val_mean_absolute_error: 14.6036
# Epoch 104/150
# 6/6 [==============================] - 2s 357ms/step - loss: 9.8161 - mean_absolute_error: 9.8161 - val_loss: 15.5005 - val_mean_absolute_error: 15.5005
# Epoch 105/150
# 6/6 [==============================] - 2s 362ms/step - loss: 9.2412 - mean_absolute_error: 9.2412 - val_loss: 16.6793 - val_mean_absolute_error: 16.6793
# Epoch 106/150
# 6/6 [==============================] - 2s 359ms/step - loss: 9.5119 - mean_absolute_error: 9.5119 - val_loss: 14.9583 - val_mean_absolute_error: 14.9583
# Epoch 107/150
# 6/6 [==============================] - 2s 354ms/step - loss: 8.4270 - mean_absolute_error: 8.4270 - val_loss: 16.7464 - val_mean_absolute_error: 16.7464
# Epoch 108/150
# 6/6 [==============================] - 2s 353ms/step - loss: 9.1635 - mean_absolute_error: 9.1635 - val_loss: 14.0130 - val_mean_absolute_error: 14.0130
# Epoch 109/150
# 6/6 [==============================] - 2s 357ms/step - loss: 9.9343 - mean_absolute_error: 9.9343 - val_loss: 16.8515 - val_mean_absolute_error: 16.8515
# Epoch 110/150
# 6/6 [==============================] - 2s 357ms/step - loss: 10.7570 - mean_absolute_error: 10.7570 - val_loss: 15.0692 - val_mean_absolute_error: 15.0692
# Epoch 111/150
# 6/6 [==============================] - 2s 358ms/step - loss: 10.1244 - mean_absolute_error: 10.1244 - val_loss: 16.1032 - val_mean_absolute_error: 16.1032
# Epoch 112/150
# 6/6 [==============================] - 2s 358ms/step - loss: 8.5176 - mean_absolute_error: 8.5176 - val_loss: 16.1736 - val_mean_absolute_error: 16.1736
# Epoch 113/150
# 6/6 [==============================] - 2s 359ms/step - loss: 9.1440 - mean_absolute_error: 9.1440 - val_loss: 15.8219 - val_mean_absolute_error: 15.8219
# Epoch 114/150
# 6/6 [==============================] - 2s 361ms/step - loss: 9.2529 - mean_absolute_error: 9.2529 - val_loss: 16.1977 - val_mean_absolute_error: 16.1977
# Epoch 115/150
# 6/6 [==============================] - 2s 363ms/step - loss: 9.3515 - mean_absolute_error: 9.3515 - val_loss: 15.6773 - val_mean_absolute_error: 15.6773
# Epoch 116/150
# 6/6 [==============================] - 2s 359ms/step - loss: 9.0926 - mean_absolute_error: 9.0926 - val_loss: 16.0906 - val_mean_absolute_error: 16.0906
# Epoch 117/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.3953 - mean_absolute_error: 9.3953 - val_loss: 15.8241 - val_mean_absolute_error: 15.8241
# Epoch 118/150
# 6/6 [==============================] - 2s 355ms/step - loss: 9.3536 - mean_absolute_error: 9.3536 - val_loss: 17.4320 - val_mean_absolute_error: 17.4320
# Epoch 119/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.5978 - mean_absolute_error: 9.5978 - val_loss: 14.7960 - val_mean_absolute_error: 14.7960
# Epoch 120/150
# 6/6 [==============================] - 2s 353ms/step - loss: 9.9087 - mean_absolute_error: 9.9087 - val_loss: 17.2283 - val_mean_absolute_error: 17.2283
# Epoch 121/150
# 6/6 [==============================] - 2s 354ms/step - loss: 9.8927 - mean_absolute_error: 9.8927 - val_loss: 14.1798 - val_mean_absolute_error: 14.1798
# Epoch 122/150
# 6/6 [==============================] - 2s 357ms/step - loss: 9.0405 - mean_absolute_error: 9.0405 - val_loss: 16.5719 - val_mean_absolute_error: 16.5719
# Epoch 123/150
# 6/6 [==============================] - 2s 356ms/step - loss: 8.9278 - mean_absolute_error: 8.9278 - val_loss: 16.6061 - val_mean_absolute_error: 16.6061
# Epoch 124/150
# 6/6 [==============================] - 2s 361ms/step - loss: 8.6030 - mean_absolute_error: 8.6030 - val_loss: 14.7752 - val_mean_absolute_error: 14.7752
# Epoch 125/150
# 6/6 [==============================] - 2s 359ms/step - loss: 8.8607 - mean_absolute_error: 8.8607 - val_loss: 17.3858 - val_mean_absolute_error: 17.3858
# Epoch 126/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.6376 - mean_absolute_error: 9.6376 - val_loss: 14.3950 - val_mean_absolute_error: 14.3950
# Epoch 127/150
# 6/6 [==============================] - 2s 357ms/step - loss: 9.5759 - mean_absolute_error: 9.5759 - val_loss: 18.1186 - val_mean_absolute_error: 18.1186
# Epoch 128/150
# 6/6 [==============================] - 2s 355ms/step - loss: 10.1039 - mean_absolute_error: 10.1039 - val_loss: 15.7591 - val_mean_absolute_error: 15.7591
# Epoch 129/150
# 6/6 [==============================] - 2s 360ms/step - loss: 9.0566 - mean_absolute_error: 9.0566 - val_loss: 15.7506 - val_mean_absolute_error: 15.7506
# Epoch 130/150
# 6/6 [==============================] - 2s 357ms/step - loss: 8.8406 - mean_absolute_error: 8.8406 - val_loss: 15.6841 - val_mean_absolute_error: 15.6841
# Epoch 131/150
# 6/6 [==============================] - 2s 357ms/step - loss: 9.8389 - mean_absolute_error: 9.8389 - val_loss: 16.3085 - val_mean_absolute_error: 16.3085
# Epoch 132/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.3670 - mean_absolute_error: 9.3670 - val_loss: 15.5126 - val_mean_absolute_error: 15.5126
# Epoch 133/150
# 6/6 [==============================] - 2s 358ms/step - loss: 10.1116 - mean_absolute_error: 10.1116 - val_loss: 17.4737 - val_mean_absolute_error: 17.4737
# Epoch 134/150
# 6/6 [==============================] - 2s 362ms/step - loss: 9.0514 - mean_absolute_error: 9.0514 - val_loss: 15.0216 - val_mean_absolute_error: 15.0216
# Epoch 135/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.6149 - mean_absolute_error: 9.6149 - val_loss: 16.6436 - val_mean_absolute_error: 16.6436
# Epoch 136/150
# 6/6 [==============================] - 2s 358ms/step - loss: 9.0622 - mean_absolute_error: 9.0622 - val_loss: 16.3830 - val_mean_absolute_error: 16.3830
# Epoch 137/150
# 6/6 [==============================] - 2s 356ms/step - loss: 8.7552 - mean_absolute_error: 8.7552 - val_loss: 16.6054 - val_mean_absolute_error: 16.6054
# Epoch 138/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.5226 - mean_absolute_error: 9.5226 - val_loss: 14.8345 - val_mean_absolute_error: 14.8345
# Epoch 139/150
# 6/6 [==============================] - 2s 367ms/step - loss: 8.5829 - mean_absolute_error: 8.5829 - val_loss: 15.5110 - val_mean_absolute_error: 15.5110
# Epoch 140/150
# 6/6 [==============================] - 2s 355ms/step - loss: 8.1816 - mean_absolute_error: 8.1816 - val_loss: 16.7638 - val_mean_absolute_error: 16.7638
# Epoch 141/150
# 6/6 [==============================] - 2s 356ms/step - loss: 9.1557 - mean_absolute_error: 9.1557 - val_loss: 15.2758 - val_mean_absolute_error: 15.2758
# Epoch 142/150
# 6/6 [==============================] - 2s 357ms/step - loss: 9.3331 - mean_absolute_error: 9.3331 - val_loss: 16.1316 - val_mean_absolute_error: 16.1316
# Epoch 143/150
# 6/6 [==============================] - 2s 359ms/step - loss: 8.4421 - mean_absolute_error: 8.4421 - val_loss: 16.8949 - val_mean_absolute_error: 16.8949
# Epoch 144/150
# 6/6 [==============================] - 2s 357ms/step - loss: 8.9500 - mean_absolute_error: 8.9500 - val_loss: 16.1849 - val_mean_absolute_error: 16.1849
# Epoch 145/150
# 6/6 [==============================] - 2s 359ms/step - loss: 8.1409 - mean_absolute_error: 8.1409 - val_loss: 15.9394 - val_mean_absolute_error: 15.9394
# Epoch 146/150
# 6/6 [==============================] - 2s 356ms/step - loss: 10.2765 - mean_absolute_error: 10.2765 - val_loss: 15.2648 - val_mean_absolute_error: 15.2648
# Epoch 147/150
# 6/6 [==============================] - 2s 358ms/step - loss: 10.1534 - mean_absolute_error: 10.1534 - val_loss: 15.8860 - val_mean_absolute_error: 15.8860
# Epoch 148/150
# 6/6 [==============================] - 2s 366ms/step - loss: 8.7728 - mean_absolute_error: 8.7728 - val_loss: 15.6453 - val_mean_absolute_error: 15.6453
# Epoch 149/150
# 6/6 [==============================] - 2s 360ms/step - loss: 9.2072 - mean_absolute_error: 9.2072 - val_loss: 15.8024 - val_mean_absolute_error: 15.8024
# Epoch 150/150
# 6/6 [==============================] - 2s 357ms/step - loss: 9.0417 - mean_absolute_error: 9.0417 - val_loss: 15.4133 - val_mean_absolute_error: 15.4133

# %%
import matplotlib.pyplot as plt
print(history.history.keys())

plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
import os

import tensorflow as tf
from tensorflow import keras

print(tf.version.VERSION)
model4.save('/content/drive/MyDrive/Grad2Models/yasGCClinic')
# Out:
# 2.8.2
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Grad2Models/yasGCClinic/assets

# %%
new_model = tf.keras.models.load_model('/content/drive/MyDrive/Grad2Models/yasGCClinic', compile=False)

# Check its architecture
new_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  conv1d_4_input (InputLayer)    [(None, 324, 1)]     0           []
#
#  conv1d_input (InputLayer)      [(None, 8, 1)]       0           []
#
#  conv1d_4 (Conv1D)              (None, 322, 256)     1024        ['conv1d_4_input[0][0]']
#
#  conv1d (Conv1D)                (None, 6, 256)       1024        ['conv1d_input[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 320, 256)     196864      ['conv1d_4[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 4, 256)       196864      ['conv1d[0][0]']
#
#  dropout_3 (Dropout)            (None, 320, 256)     0           ['conv1d_5[0][0]']
#
#  dropout (Dropout)              (None, 4, 256)       0           ['conv1d_1[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 160, 256)    0           ['dropout_3[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 2, 256)       0           ['dropout[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 158, 128)     98432       ['max_pooling1d_3[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 1, 128)       65664       ['max_pooling1d[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 79, 128)     0           ['conv1d_6[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 1, 128)      0           ['conv1d_2[0][0]']
#
#  dropout_4 (Dropout)            (None, 79, 128)      0           ['max_pooling1d_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 1, 128)       0           ['max_pooling1d_1[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 77, 64)       24640       ['dropout_4[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 1, 64)        8256        ['dropout_1[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 38, 64)      0           ['conv1d_7[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 1, 64)       0           ['conv1d_3[0][0]']
#
#  dropout_5 (Dropout)            (None, 38, 64)       0           ['max_pooling1d_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 1, 64)        0           ['max_pooling1d_2[0][0]']
#
#  flatten_1 (Flatten)            (None, 2432)         0           ['dropout_5[0][0]']
#
#  flatten (Flatten)              (None, 64)           0           ['dropout_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 2496)         0           ['flatten_1[0][0]',
#                                                                   'flatten[0][0]']
#
#  dense_2 (Dense)                (None, 16)           39952       ['concatenate_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 16)           0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 1)            17          ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 632,737
# Trainable params: 632,737
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
prediction=new_model.predict((X_test[:,197:521],X_test[:,521:529]))


    

yout=y_test.to_numpy()    
counter=0
counter2=0
counter3=0
yout = yout. astype(int)
total=0
for i in range (prediction.shape[0]):
  if prediction[i]%1>=0.5:
    prediction[i]=int(prediction[i])+1
  else :
     prediction[i]=int(prediction[i])  

for i in range (prediction.shape[0]):
  if prediction[i]>yout[i]:
    total=total+prediction[i]-yout[i]
  else:
    total=total+yout[i]-prediction[i]

print("Hata Payı = %",total/100)
# Out:
# Hata Payı = % [13.95]
