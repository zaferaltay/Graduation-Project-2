# %%
import pandas as pd
import numpy as np

urineDS=pd.read_csv("/content/drive/MyDrive/Grad2/lastUrine.csv")
urineDS=urineDS.iloc[:,1:]

from sklearn.preprocessing import StandardScaler


urineOutput=urineDS.iloc[2:,1:2]
urineInput=urineDS.iloc[2:,4:]

data = urineInput
scaler = StandardScaler()
scaler.fit(data)
urineInput=scaler.transform(data)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(urineInput, urineOutput, test_size=0.33, random_state=0)

# %%
X_train=X_train.astype(np.float64)
X_test=X_test.astype(np.float64)
y_train=y_train.astype(np.float64)
y_test=y_test.astype(np.float64)

X_train=X_train.astype(np.int64)
y_train=y_train.astype(np.int64)
X_train=X_train.astype(np.float64)
y_train=y_train.astype(np.float64)
print(y_train)
# Out:
#      Unnamed: 1
# 231        46.0
# 20         52.0
# 169        25.0
# 254        50.0
# 126        73.0
# ..          ...
# 253        30.0
# 194        60.0
# 119        61.0
# 49         61.0
# 174        62.0
#
# [201 rows x 1 columns]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Flatten,concatenate

from tensorflow.keras.optimizers import Adam
from keras.layers import Dropout
import keras
from matplotlib import pyplot as plt

model = Sequential()
model.add(Conv1D(256, 3, activation='relu', input_shape=(8, 1)))
model.add(Conv1D(256, 3, activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling1D(2))
model.add(Conv1D(128, 2, activation='relu'))
model.add(MaxPooling1D(1))
model.add(Dropout(0.25))
model.add(Conv1D(64, 1, activation='relu'))
model.add(MaxPooling1D(1))
model.add(Dropout(0.5))
model.add(Flatten())
x1=model.output

model2 = Sequential()
model2.add(Conv1D(256, 3, activation='relu', input_shape=(324, 1)))
model2.add(Conv1D(256, 3, activation='relu'))
model2.add(Dropout(0.25))
model2.add(MaxPooling1D(2))
model2.add(Conv1D(128, 3, activation='relu'))
model2.add(MaxPooling1D(2))
model2.add(Dropout(0.25))
model2.add(Conv1D(64, 3, activation='relu'))
model2.add(MaxPooling1D(2))
model2.add(Dropout(0.5))
model2.add(Flatten())
x2=model2.output

model3 = Sequential()
model3.add(Conv1D(256, 3, activation='relu', input_shape=(197, 1)))
model3.add(Conv1D(256, 3, activation='relu'))
model3.add(Dropout(0.25))
model3.add(MaxPooling1D(2))
model3.add(Conv1D(128, 3, activation='relu'))
model3.add(MaxPooling1D(2))
model3.add(Dropout(0.25))
model3.add(Conv1D(64, 3, activation='relu'))
model3.add(MaxPooling1D(2))
model3.add(Dropout(0.5))
model3.add(Flatten())
x3=model3.output

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os
import keras
from keras.models import Sequential, Model
from keras.layers import GlobalAveragePooling2D, Dense, Input, Dropout, concatenate
from keras.applications.vgg16 import VGG16
from sklearn.model_selection import train_test_split

from math import ceil
import datetime

# %%
x = concatenate([x3, x2,x1])
#x = Sequential()(x)
x = Dense(16, activation='relu')(x) 
x = Dropout(0.2)(x)
predictions = Dense(1, activation='relu')(x)


model4 = Model(inputs=[model3.input, model2.input,model.input], outputs=predictions) # Inputs go into 3 different layers
model4.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_absolute_error'])

# %%
model4.output
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_3')>

# %%
history =model4.fit((X_train[:,:197],X_train[:,197:521],X_train[:,521:529]),y_train, batch_size=32, epochs=174, validation_split=0.1)
# Out:
# Epoch 1/174
# 6/6 [==============================] - 4s 488ms/step - loss: 41.6163 - mean_absolute_error: 41.6163 - val_loss: 23.3468 - val_mean_absolute_error: 23.3468
# Epoch 2/174
# 6/6 [==============================] - 3s 443ms/step - loss: 24.3135 - mean_absolute_error: 24.3135 - val_loss: 24.1557 - val_mean_absolute_error: 24.1557
# Epoch 3/174
# 6/6 [==============================] - 3s 436ms/step - loss: 21.5503 - mean_absolute_error: 21.5503 - val_loss: 21.5369 - val_mean_absolute_error: 21.5369
# Epoch 4/174
# 6/6 [==============================] - 3s 437ms/step - loss: 19.2886 - mean_absolute_error: 19.2886 - val_loss: 20.8619 - val_mean_absolute_error: 20.8619
# Epoch 5/174
# 6/6 [==============================] - 3s 444ms/step - loss: 20.6781 - mean_absolute_error: 20.6781 - val_loss: 23.1357 - val_mean_absolute_error: 23.1357
# Epoch 6/174
# 6/6 [==============================] - 3s 442ms/step - loss: 18.2044 - mean_absolute_error: 18.2044 - val_loss: 19.5168 - val_mean_absolute_error: 19.5168
# Epoch 7/174
# 6/6 [==============================] - 3s 436ms/step - loss: 17.9247 - mean_absolute_error: 17.9247 - val_loss: 22.7563 - val_mean_absolute_error: 22.7563
# Epoch 8/174
# 6/6 [==============================] - 3s 438ms/step - loss: 19.4582 - mean_absolute_error: 19.4582 - val_loss: 19.5323 - val_mean_absolute_error: 19.5323
# Epoch 9/174
# 6/6 [==============================] - 3s 435ms/step - loss: 19.9542 - mean_absolute_error: 19.9542 - val_loss: 20.9993 - val_mean_absolute_error: 20.9993
# Epoch 10/174
# 6/6 [==============================] - 3s 434ms/step - loss: 18.9956 - mean_absolute_error: 18.9956 - val_loss: 20.8957 - val_mean_absolute_error: 20.8957
# Epoch 11/174
# 6/6 [==============================] - 3s 441ms/step - loss: 16.8565 - mean_absolute_error: 16.8565 - val_loss: 19.3784 - val_mean_absolute_error: 19.3784
# Epoch 12/174
# 6/6 [==============================] - 3s 447ms/step - loss: 16.6585 - mean_absolute_error: 16.6585 - val_loss: 20.3890 - val_mean_absolute_error: 20.3890
# Epoch 13/174
# 6/6 [==============================] - 3s 435ms/step - loss: 16.5096 - mean_absolute_error: 16.5096 - val_loss: 19.7296 - val_mean_absolute_error: 19.7296
# Epoch 14/174
# 6/6 [==============================] - 3s 441ms/step - loss: 16.9207 - mean_absolute_error: 16.9207 - val_loss: 18.8077 - val_mean_absolute_error: 18.8077
# Epoch 15/174
# 6/6 [==============================] - 3s 441ms/step - loss: 17.6026 - mean_absolute_error: 17.6026 - val_loss: 20.2149 - val_mean_absolute_error: 20.2149
# Epoch 16/174
# 6/6 [==============================] - 3s 449ms/step - loss: 16.2240 - mean_absolute_error: 16.2240 - val_loss: 16.7873 - val_mean_absolute_error: 16.7873
# Epoch 17/174
# 6/6 [==============================] - 3s 442ms/step - loss: 15.3320 - mean_absolute_error: 15.3320 - val_loss: 21.4261 - val_mean_absolute_error: 21.4261
# Epoch 18/174
# 6/6 [==============================] - 3s 429ms/step - loss: 15.6692 - mean_absolute_error: 15.6692 - val_loss: 16.0982 - val_mean_absolute_error: 16.0982
# Epoch 19/174
# 6/6 [==============================] - 3s 433ms/step - loss: 14.8508 - mean_absolute_error: 14.8508 - val_loss: 19.7224 - val_mean_absolute_error: 19.7224
# Epoch 20/174
# 6/6 [==============================] - 3s 435ms/step - loss: 15.0160 - mean_absolute_error: 15.0160 - val_loss: 17.0809 - val_mean_absolute_error: 17.0809
# Epoch 21/174
# 6/6 [==============================] - 3s 439ms/step - loss: 14.6027 - mean_absolute_error: 14.6027 - val_loss: 17.6897 - val_mean_absolute_error: 17.6897
# Epoch 22/174
# 6/6 [==============================] - 3s 435ms/step - loss: 13.9722 - mean_absolute_error: 13.9722 - val_loss: 16.4142 - val_mean_absolute_error: 16.4142
# Epoch 23/174
# 6/6 [==============================] - 3s 430ms/step - loss: 13.2471 - mean_absolute_error: 13.2471 - val_loss: 16.7763 - val_mean_absolute_error: 16.7763
# Epoch 24/174
# 6/6 [==============================] - 3s 583ms/step - loss: 14.8562 - mean_absolute_error: 14.8562 - val_loss: 20.4339 - val_mean_absolute_error: 20.4339
# Epoch 25/174
# 6/6 [==============================] - 4s 561ms/step - loss: 15.3010 - mean_absolute_error: 15.3010 - val_loss: 15.5405 - val_mean_absolute_error: 15.5405
# Epoch 26/174
# 6/6 [==============================] - 3s 441ms/step - loss: 14.6726 - mean_absolute_error: 14.6726 - val_loss: 20.8526 - val_mean_absolute_error: 20.8526
# Epoch 27/174
# 6/6 [==============================] - 3s 437ms/step - loss: 14.7041 - mean_absolute_error: 14.7041 - val_loss: 14.5620 - val_mean_absolute_error: 14.5620
# Epoch 28/174
# 6/6 [==============================] - 3s 437ms/step - loss: 15.4611 - mean_absolute_error: 15.4611 - val_loss: 20.4226 - val_mean_absolute_error: 20.4226
# Epoch 29/174
# 6/6 [==============================] - 3s 437ms/step - loss: 13.4358 - mean_absolute_error: 13.4358 - val_loss: 15.6208 - val_mean_absolute_error: 15.6208
# Epoch 30/174
# 6/6 [==============================] - 3s 436ms/step - loss: 12.8603 - mean_absolute_error: 12.8603 - val_loss: 21.8104 - val_mean_absolute_error: 21.8104
# Epoch 31/174
# 6/6 [==============================] - 3s 436ms/step - loss: 14.4038 - mean_absolute_error: 14.4038 - val_loss: 15.2012 - val_mean_absolute_error: 15.2012
# Epoch 32/174
# 6/6 [==============================] - 3s 435ms/step - loss: 15.0679 - mean_absolute_error: 15.0679 - val_loss: 19.9083 - val_mean_absolute_error: 19.9083
# Epoch 33/174
# 6/6 [==============================] - 3s 429ms/step - loss: 13.7510 - mean_absolute_error: 13.7510 - val_loss: 16.3105 - val_mean_absolute_error: 16.3105
# Epoch 34/174
# 6/6 [==============================] - 3s 438ms/step - loss: 12.3775 - mean_absolute_error: 12.3775 - val_loss: 17.2334 - val_mean_absolute_error: 17.2334
# Epoch 35/174
# 6/6 [==============================] - 3s 443ms/step - loss: 11.6296 - mean_absolute_error: 11.6296 - val_loss: 17.0405 - val_mean_absolute_error: 17.0405
# Epoch 36/174
# 6/6 [==============================] - 3s 440ms/step - loss: 12.8372 - mean_absolute_error: 12.8372 - val_loss: 18.1691 - val_mean_absolute_error: 18.1691
# Epoch 37/174
# 6/6 [==============================] - 3s 438ms/step - loss: 12.1429 - mean_absolute_error: 12.1429 - val_loss: 16.9903 - val_mean_absolute_error: 16.9903
# Epoch 38/174
# 6/6 [==============================] - 3s 444ms/step - loss: 12.8507 - mean_absolute_error: 12.8507 - val_loss: 15.0600 - val_mean_absolute_error: 15.0600
# Epoch 39/174
# 6/6 [==============================] - 3s 440ms/step - loss: 13.2142 - mean_absolute_error: 13.2142 - val_loss: 16.6369 - val_mean_absolute_error: 16.6369
# Epoch 40/174
# 6/6 [==============================] - 3s 439ms/step - loss: 12.5829 - mean_absolute_error: 12.5829 - val_loss: 17.9412 - val_mean_absolute_error: 17.9412
# Epoch 41/174
# 6/6 [==============================] - 3s 443ms/step - loss: 11.4051 - mean_absolute_error: 11.4051 - val_loss: 15.3330 - val_mean_absolute_error: 15.3330
# Epoch 42/174
# 6/6 [==============================] - 3s 438ms/step - loss: 13.1895 - mean_absolute_error: 13.1895 - val_loss: 18.9274 - val_mean_absolute_error: 18.9274
# Epoch 43/174
# 6/6 [==============================] - 3s 435ms/step - loss: 12.8754 - mean_absolute_error: 12.8754 - val_loss: 15.2702 - val_mean_absolute_error: 15.2702
# Epoch 44/174
# 6/6 [==============================] - 3s 442ms/step - loss: 11.9684 - mean_absolute_error: 11.9684 - val_loss: 18.3807 - val_mean_absolute_error: 18.3807
# Epoch 45/174
# 6/6 [==============================] - 3s 440ms/step - loss: 11.7996 - mean_absolute_error: 11.7996 - val_loss: 14.9734 - val_mean_absolute_error: 14.9734
# Epoch 46/174
# 6/6 [==============================] - 3s 442ms/step - loss: 12.4606 - mean_absolute_error: 12.4606 - val_loss: 18.8699 - val_mean_absolute_error: 18.8699
# Epoch 47/174
# 6/6 [==============================] - 3s 442ms/step - loss: 13.2090 - mean_absolute_error: 13.2090 - val_loss: 15.8086 - val_mean_absolute_error: 15.8086
# Epoch 48/174
# 6/6 [==============================] - 3s 436ms/step - loss: 11.5268 - mean_absolute_error: 11.5268 - val_loss: 15.7659 - val_mean_absolute_error: 15.7659
# Epoch 49/174
# 6/6 [==============================] - 3s 437ms/step - loss: 11.9321 - mean_absolute_error: 11.9321 - val_loss: 15.1382 - val_mean_absolute_error: 15.1382
# Epoch 50/174
# 6/6 [==============================] - 3s 442ms/step - loss: 11.6872 - mean_absolute_error: 11.6872 - val_loss: 17.7765 - val_mean_absolute_error: 17.7765
# Epoch 51/174
# 6/6 [==============================] - 3s 440ms/step - loss: 11.1942 - mean_absolute_error: 11.1942 - val_loss: 15.3914 - val_mean_absolute_error: 15.3914
# Epoch 52/174
# 6/6 [==============================] - 3s 438ms/step - loss: 11.5907 - mean_absolute_error: 11.5907 - val_loss: 17.4723 - val_mean_absolute_error: 17.4723
# Epoch 53/174
# 6/6 [==============================] - 3s 439ms/step - loss: 12.2957 - mean_absolute_error: 12.2957 - val_loss: 15.6999 - val_mean_absolute_error: 15.6999
# Epoch 54/174
# 6/6 [==============================] - 3s 441ms/step - loss: 10.5808 - mean_absolute_error: 10.5808 - val_loss: 16.1243 - val_mean_absolute_error: 16.1243
# Epoch 55/174
# 6/6 [==============================] - 3s 440ms/step - loss: 10.1900 - mean_absolute_error: 10.1900 - val_loss: 14.7305 - val_mean_absolute_error: 14.7305
# Epoch 56/174
# 6/6 [==============================] - 3s 437ms/step - loss: 11.4859 - mean_absolute_error: 11.4859 - val_loss: 16.4660 - val_mean_absolute_error: 16.4660
# Epoch 57/174
# 6/6 [==============================] - 3s 432ms/step - loss: 11.7056 - mean_absolute_error: 11.7056 - val_loss: 14.1675 - val_mean_absolute_error: 14.1675
# Epoch 58/174
# 6/6 [==============================] - 3s 438ms/step - loss: 11.6470 - mean_absolute_error: 11.6470 - val_loss: 15.5550 - val_mean_absolute_error: 15.5550
# Epoch 59/174
# 6/6 [==============================] - 3s 440ms/step - loss: 11.1036 - mean_absolute_error: 11.1036 - val_loss: 17.8015 - val_mean_absolute_error: 17.8015
# Epoch 60/174
# 6/6 [==============================] - 3s 444ms/step - loss: 12.7653 - mean_absolute_error: 12.7653 - val_loss: 15.0233 - val_mean_absolute_error: 15.0233
# Epoch 61/174
# 6/6 [==============================] - 3s 445ms/step - loss: 10.0676 - mean_absolute_error: 10.0676 - val_loss: 15.8489 - val_mean_absolute_error: 15.8489
# Epoch 62/174
# 6/6 [==============================] - 3s 443ms/step - loss: 10.6951 - mean_absolute_error: 10.6951 - val_loss: 14.8992 - val_mean_absolute_error: 14.8992
# Epoch 63/174
# 6/6 [==============================] - 3s 446ms/step - loss: 11.5633 - mean_absolute_error: 11.5633 - val_loss: 16.2564 - val_mean_absolute_error: 16.2564
# Epoch 64/174
# 6/6 [==============================] - 3s 453ms/step - loss: 10.1816 - mean_absolute_error: 10.1816 - val_loss: 15.6496 - val_mean_absolute_error: 15.6496
# Epoch 65/174
# 6/6 [==============================] - 3s 439ms/step - loss: 11.1408 - mean_absolute_error: 11.1408 - val_loss: 15.4993 - val_mean_absolute_error: 15.4993
# Epoch 66/174
# 6/6 [==============================] - 3s 440ms/step - loss: 10.7053 - mean_absolute_error: 10.7053 - val_loss: 14.7283 - val_mean_absolute_error: 14.7283
# Epoch 67/174
# 6/6 [==============================] - 3s 448ms/step - loss: 10.5931 - mean_absolute_error: 10.5931 - val_loss: 16.0509 - val_mean_absolute_error: 16.0509
# Epoch 68/174
# 6/6 [==============================] - 3s 442ms/step - loss: 9.6081 - mean_absolute_error: 9.6081 - val_loss: 14.7450 - val_mean_absolute_error: 14.7450
# Epoch 69/174
# 6/6 [==============================] - 3s 442ms/step - loss: 10.5674 - mean_absolute_error: 10.5674 - val_loss: 14.8918 - val_mean_absolute_error: 14.8918
# Epoch 70/174
# 6/6 [==============================] - 3s 450ms/step - loss: 10.4945 - mean_absolute_error: 10.4945 - val_loss: 14.4045 - val_mean_absolute_error: 14.4045
# Epoch 71/174
# 6/6 [==============================] - 3s 442ms/step - loss: 11.9159 - mean_absolute_error: 11.9159 - val_loss: 15.8446 - val_mean_absolute_error: 15.8446
# Epoch 72/174
# 6/6 [==============================] - 3s 444ms/step - loss: 11.5153 - mean_absolute_error: 11.5153 - val_loss: 17.9312 - val_mean_absolute_error: 17.9312
# Epoch 73/174
# 6/6 [==============================] - 3s 440ms/step - loss: 11.9349 - mean_absolute_error: 11.9349 - val_loss: 14.9040 - val_mean_absolute_error: 14.9040
# Epoch 74/174
# 6/6 [==============================] - 3s 443ms/step - loss: 11.5827 - mean_absolute_error: 11.5827 - val_loss: 18.2133 - val_mean_absolute_error: 18.2133
# Epoch 75/174
# 6/6 [==============================] - 3s 450ms/step - loss: 10.8663 - mean_absolute_error: 10.8663 - val_loss: 14.6482 - val_mean_absolute_error: 14.6482
# Epoch 76/174
# 6/6 [==============================] - 3s 444ms/step - loss: 9.8700 - mean_absolute_error: 9.8700 - val_loss: 14.5396 - val_mean_absolute_error: 14.5396
# Epoch 77/174
# 6/6 [==============================] - 3s 449ms/step - loss: 12.2694 - mean_absolute_error: 12.2694 - val_loss: 15.1228 - val_mean_absolute_error: 15.1228
# Epoch 78/174
# 6/6 [==============================] - 3s 438ms/step - loss: 10.3563 - mean_absolute_error: 10.3563 - val_loss: 14.4954 - val_mean_absolute_error: 14.4954
# Epoch 79/174
# 6/6 [==============================] - 3s 437ms/step - loss: 11.8689 - mean_absolute_error: 11.8689 - val_loss: 16.0746 - val_mean_absolute_error: 16.0746
# Epoch 80/174
# 6/6 [==============================] - 3s 439ms/step - loss: 11.6677 - mean_absolute_error: 11.6677 - val_loss: 14.7148 - val_mean_absolute_error: 14.7148
# Epoch 81/174
# 6/6 [==============================] - 3s 446ms/step - loss: 8.9317 - mean_absolute_error: 8.9317 - val_loss: 15.6576 - val_mean_absolute_error: 15.6576
# Epoch 82/174
# 6/6 [==============================] - 3s 450ms/step - loss: 9.6419 - mean_absolute_error: 9.6419 - val_loss: 15.8006 - val_mean_absolute_error: 15.8006
# Epoch 83/174
# 6/6 [==============================] - 3s 437ms/step - loss: 10.2400 - mean_absolute_error: 10.2400 - val_loss: 16.7386 - val_mean_absolute_error: 16.7386
# Epoch 84/174
# 6/6 [==============================] - 3s 443ms/step - loss: 9.6336 - mean_absolute_error: 9.6336 - val_loss: 15.1612 - val_mean_absolute_error: 15.1612
# Epoch 85/174
# 6/6 [==============================] - 3s 444ms/step - loss: 9.9174 - mean_absolute_error: 9.9174 - val_loss: 14.8453 - val_mean_absolute_error: 14.8453
# Epoch 86/174
# 6/6 [==============================] - 3s 443ms/step - loss: 10.0018 - mean_absolute_error: 10.0018 - val_loss: 19.3420 - val_mean_absolute_error: 19.3420
# Epoch 87/174
# 6/6 [==============================] - 3s 439ms/step - loss: 10.5507 - mean_absolute_error: 10.5507 - val_loss: 15.3269 - val_mean_absolute_error: 15.3269
# Epoch 88/174
# 6/6 [==============================] - 3s 433ms/step - loss: 10.5655 - mean_absolute_error: 10.5655 - val_loss: 16.6708 - val_mean_absolute_error: 16.6708
# Epoch 89/174
# 6/6 [==============================] - 3s 446ms/step - loss: 10.2106 - mean_absolute_error: 10.2106 - val_loss: 14.2289 - val_mean_absolute_error: 14.2289
# Epoch 90/174
# 6/6 [==============================] - 3s 443ms/step - loss: 9.9751 - mean_absolute_error: 9.9751 - val_loss: 17.4922 - val_mean_absolute_error: 17.4922
# Epoch 91/174
# 6/6 [==============================] - 3s 446ms/step - loss: 9.3565 - mean_absolute_error: 9.3565 - val_loss: 14.9946 - val_mean_absolute_error: 14.9946
# Epoch 92/174
# 6/6 [==============================] - 3s 446ms/step - loss: 10.3087 - mean_absolute_error: 10.3087 - val_loss: 17.5023 - val_mean_absolute_error: 17.5023
# Epoch 93/174
# 6/6 [==============================] - 3s 441ms/step - loss: 9.5982 - mean_absolute_error: 9.5982 - val_loss: 14.5107 - val_mean_absolute_error: 14.5107
# Epoch 94/174
# 6/6 [==============================] - 3s 441ms/step - loss: 9.4928 - mean_absolute_error: 9.4928 - val_loss: 15.9058 - val_mean_absolute_error: 15.9058
# Epoch 95/174
# 6/6 [==============================] - 3s 434ms/step - loss: 9.9703 - mean_absolute_error: 9.9703 - val_loss: 13.5637 - val_mean_absolute_error: 13.5637
# Epoch 96/174
# 6/6 [==============================] - 3s 438ms/step - loss: 9.7900 - mean_absolute_error: 9.7900 - val_loss: 14.9320 - val_mean_absolute_error: 14.9320
# Epoch 97/174
# 6/6 [==============================] - 3s 442ms/step - loss: 9.6715 - mean_absolute_error: 9.6715 - val_loss: 14.9930 - val_mean_absolute_error: 14.9930
# Epoch 98/174
# 6/6 [==============================] - 3s 442ms/step - loss: 9.1464 - mean_absolute_error: 9.1464 - val_loss: 14.4980 - val_mean_absolute_error: 14.4980
# Epoch 99/174
# 6/6 [==============================] - 3s 439ms/step - loss: 8.8546 - mean_absolute_error: 8.8546 - val_loss: 15.2974 - val_mean_absolute_error: 15.2974
# Epoch 100/174
# 6/6 [==============================] - 3s 442ms/step - loss: 9.5678 - mean_absolute_error: 9.5678 - val_loss: 14.8354 - val_mean_absolute_error: 14.8354
# Epoch 101/174
# 6/6 [==============================] - 3s 442ms/step - loss: 10.2346 - mean_absolute_error: 10.2346 - val_loss: 15.4654 - val_mean_absolute_error: 15.4654
# Epoch 102/174
# 6/6 [==============================] - 3s 434ms/step - loss: 9.6746 - mean_absolute_error: 9.6746 - val_loss: 14.6781 - val_mean_absolute_error: 14.6781
# Epoch 103/174
# 6/6 [==============================] - 3s 438ms/step - loss: 8.7232 - mean_absolute_error: 8.7232 - val_loss: 15.1485 - val_mean_absolute_error: 15.1485
# Epoch 104/174
# 6/6 [==============================] - 3s 440ms/step - loss: 8.3244 - mean_absolute_error: 8.3244 - val_loss: 14.6780 - val_mean_absolute_error: 14.6780
# Epoch 105/174
# 6/6 [==============================] - 3s 445ms/step - loss: 7.8581 - mean_absolute_error: 7.8581 - val_loss: 13.2792 - val_mean_absolute_error: 13.2792
# Epoch 106/174
# 6/6 [==============================] - 3s 443ms/step - loss: 9.2375 - mean_absolute_error: 9.2375 - val_loss: 15.7900 - val_mean_absolute_error: 15.7900
# Epoch 107/174
# 6/6 [==============================] - 3s 435ms/step - loss: 9.0565 - mean_absolute_error: 9.0565 - val_loss: 13.1929 - val_mean_absolute_error: 13.1929
# Epoch 108/174
# 6/6 [==============================] - 3s 442ms/step - loss: 9.0033 - mean_absolute_error: 9.0033 - val_loss: 14.8583 - val_mean_absolute_error: 14.8583
# Epoch 109/174
# 6/6 [==============================] - 3s 443ms/step - loss: 9.5750 - mean_absolute_error: 9.5750 - val_loss: 14.6256 - val_mean_absolute_error: 14.6256
# Epoch 110/174
# 6/6 [==============================] - 3s 450ms/step - loss: 8.5555 - mean_absolute_error: 8.5555 - val_loss: 14.7083 - val_mean_absolute_error: 14.7083
# Epoch 111/174
# 6/6 [==============================] - 3s 444ms/step - loss: 8.5650 - mean_absolute_error: 8.5650 - val_loss: 14.5605 - val_mean_absolute_error: 14.5605
# Epoch 112/174
# 6/6 [==============================] - 3s 444ms/step - loss: 8.4828 - mean_absolute_error: 8.4828 - val_loss: 13.8239 - val_mean_absolute_error: 13.8239
# Epoch 113/174
# 6/6 [==============================] - 3s 438ms/step - loss: 8.6463 - mean_absolute_error: 8.6463 - val_loss: 12.7503 - val_mean_absolute_error: 12.7503
# Epoch 114/174
# 6/6 [==============================] - 3s 441ms/step - loss: 8.9001 - mean_absolute_error: 8.9001 - val_loss: 14.2778 - val_mean_absolute_error: 14.2778
# Epoch 115/174
# 6/6 [==============================] - 3s 447ms/step - loss: 7.6239 - mean_absolute_error: 7.6239 - val_loss: 16.5863 - val_mean_absolute_error: 16.5863
# Epoch 116/174
# 6/6 [==============================] - 3s 442ms/step - loss: 8.2013 - mean_absolute_error: 8.2013 - val_loss: 15.6660 - val_mean_absolute_error: 15.6660
# Epoch 117/174
# 6/6 [==============================] - 3s 444ms/step - loss: 8.9668 - mean_absolute_error: 8.9668 - val_loss: 15.9628 - val_mean_absolute_error: 15.9628
# Epoch 118/174
# 6/6 [==============================] - 3s 443ms/step - loss: 9.4522 - mean_absolute_error: 9.4522 - val_loss: 13.8590 - val_mean_absolute_error: 13.8590
# Epoch 119/174
# 6/6 [==============================] - 3s 442ms/step - loss: 9.9097 - mean_absolute_error: 9.9097 - val_loss: 14.5094 - val_mean_absolute_error: 14.5094
# Epoch 120/174
# 6/6 [==============================] - 3s 436ms/step - loss: 8.8577 - mean_absolute_error: 8.8577 - val_loss: 14.2292 - val_mean_absolute_error: 14.2292
# Epoch 121/174
# 6/6 [==============================] - 3s 444ms/step - loss: 8.2099 - mean_absolute_error: 8.2099 - val_loss: 14.1288 - val_mean_absolute_error: 14.1288
# Epoch 122/174
# 6/6 [==============================] - 3s 447ms/step - loss: 9.3757 - mean_absolute_error: 9.3757 - val_loss: 14.7660 - val_mean_absolute_error: 14.7660
# Epoch 123/174
# 6/6 [==============================] - 3s 439ms/step - loss: 7.3854 - mean_absolute_error: 7.3854 - val_loss: 14.3304 - val_mean_absolute_error: 14.3304
# Epoch 124/174
# 6/6 [==============================] - 3s 441ms/step - loss: 8.2507 - mean_absolute_error: 8.2507 - val_loss: 15.9116 - val_mean_absolute_error: 15.9116
# Epoch 125/174
# 6/6 [==============================] - 3s 438ms/step - loss: 9.6912 - mean_absolute_error: 9.6912 - val_loss: 13.3960 - val_mean_absolute_error: 13.3960
# Epoch 126/174
# 6/6 [==============================] - 3s 442ms/step - loss: 9.3023 - mean_absolute_error: 9.3023 - val_loss: 14.7270 - val_mean_absolute_error: 14.7270
# Epoch 127/174
# 6/6 [==============================] - 3s 439ms/step - loss: 8.3860 - mean_absolute_error: 8.3860 - val_loss: 13.7563 - val_mean_absolute_error: 13.7563
# Epoch 128/174
# 6/6 [==============================] - 3s 442ms/step - loss: 8.6441 - mean_absolute_error: 8.6441 - val_loss: 14.4536 - val_mean_absolute_error: 14.4536
# Epoch 129/174
# 6/6 [==============================] - 3s 444ms/step - loss: 8.7667 - mean_absolute_error: 8.7667 - val_loss: 13.7724 - val_mean_absolute_error: 13.7724
# Epoch 130/174
# 6/6 [==============================] - 3s 443ms/step - loss: 8.0702 - mean_absolute_error: 8.0702 - val_loss: 14.1595 - val_mean_absolute_error: 14.1595
# Epoch 131/174
# 6/6 [==============================] - 3s 433ms/step - loss: 8.5384 - mean_absolute_error: 8.5384 - val_loss: 14.9622 - val_mean_absolute_error: 14.9622
# Epoch 132/174
# 6/6 [==============================] - 3s 444ms/step - loss: 8.8920 - mean_absolute_error: 8.8920 - val_loss: 14.9899 - val_mean_absolute_error: 14.9899
# Epoch 133/174
# 6/6 [==============================] - 3s 445ms/step - loss: 9.2907 - mean_absolute_error: 9.2907 - val_loss: 14.3709 - val_mean_absolute_error: 14.3709
# Epoch 134/174
# 6/6 [==============================] - 3s 436ms/step - loss: 8.9361 - mean_absolute_error: 8.9361 - val_loss: 13.5083 - val_mean_absolute_error: 13.5083
# Epoch 135/174
# 6/6 [==============================] - 3s 437ms/step - loss: 8.0190 - mean_absolute_error: 8.0190 - val_loss: 13.5450 - val_mean_absolute_error: 13.5450
# Epoch 136/174
# 6/6 [==============================] - 3s 440ms/step - loss: 8.9047 - mean_absolute_error: 8.9047 - val_loss: 13.9837 - val_mean_absolute_error: 13.9837
# Epoch 137/174
# 6/6 [==============================] - 3s 438ms/step - loss: 7.8418 - mean_absolute_error: 7.8418 - val_loss: 14.3155 - val_mean_absolute_error: 14.3155
# Epoch 138/174
# 6/6 [==============================] - 3s 440ms/step - loss: 7.9940 - mean_absolute_error: 7.9940 - val_loss: 14.7435 - val_mean_absolute_error: 14.7435
# Epoch 139/174
# 6/6 [==============================] - 3s 438ms/step - loss: 8.4733 - mean_absolute_error: 8.4733 - val_loss: 13.8354 - val_mean_absolute_error: 13.8354
# Epoch 140/174
# 6/6 [==============================] - 3s 431ms/step - loss: 8.1114 - mean_absolute_error: 8.1114 - val_loss: 13.3062 - val_mean_absolute_error: 13.3062
# Epoch 141/174
# 6/6 [==============================] - 3s 432ms/step - loss: 8.4909 - mean_absolute_error: 8.4909 - val_loss: 13.8971 - val_mean_absolute_error: 13.8971
# Epoch 142/174
# 6/6 [==============================] - 3s 434ms/step - loss: 8.0047 - mean_absolute_error: 8.0047 - val_loss: 14.6842 - val_mean_absolute_error: 14.6842
# Epoch 143/174
# 6/6 [==============================] - 3s 441ms/step - loss: 7.7184 - mean_absolute_error: 7.7184 - val_loss: 15.1699 - val_mean_absolute_error: 15.1699
# Epoch 144/174
# 6/6 [==============================] - 3s 441ms/step - loss: 8.4290 - mean_absolute_error: 8.4290 - val_loss: 13.6473 - val_mean_absolute_error: 13.6473
# Epoch 145/174
# 6/6 [==============================] - 3s 436ms/step - loss: 9.2047 - mean_absolute_error: 9.2047 - val_loss: 13.1828 - val_mean_absolute_error: 13.1828
# Epoch 146/174
# 6/6 [==============================] - 3s 440ms/step - loss: 8.8692 - mean_absolute_error: 8.8692 - val_loss: 14.4675 - val_mean_absolute_error: 14.4675
# Epoch 147/174
# 6/6 [==============================] - 3s 436ms/step - loss: 8.4398 - mean_absolute_error: 8.4398 - val_loss: 15.6330 - val_mean_absolute_error: 15.6330
# Epoch 148/174
# 6/6 [==============================] - 3s 435ms/step - loss: 8.9283 - mean_absolute_error: 8.9283 - val_loss: 15.1458 - val_mean_absolute_error: 15.1458
# Epoch 149/174
# 6/6 [==============================] - 3s 442ms/step - loss: 8.1233 - mean_absolute_error: 8.1233 - val_loss: 14.3908 - val_mean_absolute_error: 14.3908
# Epoch 150/174
# 6/6 [==============================] - 3s 441ms/step - loss: 8.4126 - mean_absolute_error: 8.4126 - val_loss: 14.8370 - val_mean_absolute_error: 14.8370
# Epoch 151/174
# 6/6 [==============================] - 3s 447ms/step - loss: 9.2151 - mean_absolute_error: 9.2151 - val_loss: 14.7171 - val_mean_absolute_error: 14.7171
# Epoch 152/174
# 6/6 [==============================] - 3s 438ms/step - loss: 8.3303 - mean_absolute_error: 8.3303 - val_loss: 14.5234 - val_mean_absolute_error: 14.5234
# Epoch 153/174
# 6/6 [==============================] - 3s 439ms/step - loss: 7.8483 - mean_absolute_error: 7.8483 - val_loss: 14.0584 - val_mean_absolute_error: 14.0584
# Epoch 154/174
# 6/6 [==============================] - 3s 437ms/step - loss: 7.6569 - mean_absolute_error: 7.6569 - val_loss: 14.8063 - val_mean_absolute_error: 14.8063
# Epoch 155/174
# 6/6 [==============================] - 3s 440ms/step - loss: 8.1171 - mean_absolute_error: 8.1171 - val_loss: 13.8903 - val_mean_absolute_error: 13.8903
# Epoch 156/174
# 6/6 [==============================] - 3s 439ms/step - loss: 8.1523 - mean_absolute_error: 8.1523 - val_loss: 14.7068 - val_mean_absolute_error: 14.7068
# Epoch 157/174
# 6/6 [==============================] - 3s 443ms/step - loss: 8.3154 - mean_absolute_error: 8.3154 - val_loss: 13.8776 - val_mean_absolute_error: 13.8776
# Epoch 158/174
# 6/6 [==============================] - 3s 439ms/step - loss: 7.6340 - mean_absolute_error: 7.6340 - val_loss: 14.9632 - val_mean_absolute_error: 14.9632
# Epoch 159/174
# 6/6 [==============================] - 3s 434ms/step - loss: 7.9811 - mean_absolute_error: 7.9811 - val_loss: 15.9832 - val_mean_absolute_error: 15.9832
# Epoch 160/174
# 6/6 [==============================] - 3s 437ms/step - loss: 7.8711 - mean_absolute_error: 7.8711 - val_loss: 14.5273 - val_mean_absolute_error: 14.5273
# Epoch 161/174
# 6/6 [==============================] - 3s 430ms/step - loss: 6.7461 - mean_absolute_error: 6.7461 - val_loss: 14.1162 - val_mean_absolute_error: 14.1162
# Epoch 162/174
# 6/6 [==============================] - 3s 433ms/step - loss: 7.9822 - mean_absolute_error: 7.9822 - val_loss: 14.3209 - val_mean_absolute_error: 14.3209
# Epoch 163/174
# 6/6 [==============================] - 3s 436ms/step - loss: 8.0627 - mean_absolute_error: 8.0627 - val_loss: 15.4160 - val_mean_absolute_error: 15.4160
# Epoch 164/174
# 6/6 [==============================] - 3s 431ms/step - loss: 8.5289 - mean_absolute_error: 8.5289 - val_loss: 13.2666 - val_mean_absolute_error: 13.2666
# Epoch 165/174
# 6/6 [==============================] - 3s 440ms/step - loss: 8.6754 - mean_absolute_error: 8.6754 - val_loss: 14.9541 - val_mean_absolute_error: 14.9541
# Epoch 166/174
# 6/6 [==============================] - 3s 438ms/step - loss: 9.1138 - mean_absolute_error: 9.1138 - val_loss: 13.6126 - val_mean_absolute_error: 13.6126
# Epoch 167/174
# 6/6 [==============================] - 3s 431ms/step - loss: 8.0647 - mean_absolute_error: 8.0647 - val_loss: 14.7271 - val_mean_absolute_error: 14.7271
# Epoch 168/174
# 6/6 [==============================] - 3s 435ms/step - loss: 8.3767 - mean_absolute_error: 8.3767 - val_loss: 13.3368 - val_mean_absolute_error: 13.3368
# Epoch 169/174
# 6/6 [==============================] - 3s 434ms/step - loss: 7.6302 - mean_absolute_error: 7.6302 - val_loss: 14.2046 - val_mean_absolute_error: 14.2046
# Epoch 170/174
# 6/6 [==============================] - 3s 436ms/step - loss: 8.3462 - mean_absolute_error: 8.3462 - val_loss: 14.5980 - val_mean_absolute_error: 14.5980
# Epoch 171/174
# 6/6 [==============================] - 3s 437ms/step - loss: 7.5415 - mean_absolute_error: 7.5415 - val_loss: 15.7186 - val_mean_absolute_error: 15.7186
# Epoch 172/174
# 6/6 [==============================] - 3s 440ms/step - loss: 7.9953 - mean_absolute_error: 7.9953 - val_loss: 14.5070 - val_mean_absolute_error: 14.5070
# Epoch 173/174
# 6/6 [==============================] - 3s 438ms/step - loss: 7.9881 - mean_absolute_error: 7.9881 - val_loss: 15.2139 - val_mean_absolute_error: 15.2139
# Epoch 174/174
# 6/6 [==============================] - 3s 439ms/step - loss: 8.7866 - mean_absolute_error: 8.7866 - val_loss: 14.2563 - val_mean_absolute_error: 14.2563

# %%
import matplotlib.pyplot as plt
print(history.history.keys())

plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
import os

import tensorflow as tf
from tensorflow import keras

print(tf.version.VERSION)
model4.save('/content/drive/MyDrive/Grad2Models/yasLate')
# Out:
# 2.8.2
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Grad2Models/yasLate/assets

# %%
new_model = tf.keras.models.load_model('/content/drive/MyDrive/Grad2Models/yasLate', compile=False)

# Check its architecture
new_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  conv1d_21_input (InputLayer)   [(None, 197, 1)]     0           []
#
#  conv1d_17_input (InputLayer)   [(None, 324, 1)]     0           []
#
#  conv1d_13_input (InputLayer)   [(None, 8, 1)]       0           []
#
#  conv1d_21 (Conv1D)             (None, 195, 256)     1024        ['conv1d_21_input[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 322, 256)     1024        ['conv1d_17_input[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 6, 256)       1024        ['conv1d_13_input[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 193, 256)     196864      ['conv1d_21[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 320, 256)     196864      ['conv1d_17[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 4, 256)       196864      ['conv1d_13[0][0]']
#
#  dropout_16 (Dropout)           (None, 193, 256)     0           ['conv1d_22[0][0]']
#
#  dropout_13 (Dropout)           (None, 320, 256)     0           ['conv1d_18[0][0]']
#
#  dropout_10 (Dropout)           (None, 4, 256)       0           ['conv1d_14[0][0]']
#
#  max_pooling1d_15 (MaxPooling1D  (None, 96, 256)     0           ['dropout_16[0][0]']
#  )
#
#  max_pooling1d_12 (MaxPooling1D  (None, 160, 256)    0           ['dropout_13[0][0]']
#  )
#
#  max_pooling1d_9 (MaxPooling1D)  (None, 2, 256)      0           ['dropout_10[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 94, 128)      98432       ['max_pooling1d_15[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 158, 128)     98432       ['max_pooling1d_12[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 1, 128)       65664       ['max_pooling1d_9[0][0]']
#
#  max_pooling1d_16 (MaxPooling1D  (None, 47, 128)     0           ['conv1d_23[0][0]']
#  )
#
#  max_pooling1d_13 (MaxPooling1D  (None, 79, 128)     0           ['conv1d_19[0][0]']
#  )
#
#  max_pooling1d_10 (MaxPooling1D  (None, 1, 128)      0           ['conv1d_15[0][0]']
#  )
#
#  dropout_17 (Dropout)           (None, 47, 128)      0           ['max_pooling1d_16[0][0]']
#
#  dropout_14 (Dropout)           (None, 79, 128)      0           ['max_pooling1d_13[0][0]']
#
#  dropout_11 (Dropout)           (None, 1, 128)       0           ['max_pooling1d_10[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 45, 64)       24640       ['dropout_17[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 77, 64)       24640       ['dropout_14[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 1, 64)        8256        ['dropout_11[0][0]']
#
#  max_pooling1d_17 (MaxPooling1D  (None, 22, 64)      0           ['conv1d_24[0][0]']
#  )
#
#  max_pooling1d_14 (MaxPooling1D  (None, 38, 64)      0           ['conv1d_20[0][0]']
#  )
#
#  max_pooling1d_11 (MaxPooling1D  (None, 1, 64)       0           ['conv1d_16[0][0]']
#  )
#
#  dropout_18 (Dropout)           (None, 22, 64)       0           ['max_pooling1d_17[0][0]']
#
#  dropout_15 (Dropout)           (None, 38, 64)       0           ['max_pooling1d_14[0][0]']
#
#  dropout_12 (Dropout)           (None, 1, 64)        0           ['max_pooling1d_11[0][0]']
#
#  flatten_5 (Flatten)            (None, 1408)         0           ['dropout_18[0][0]']
#
#  flatten_4 (Flatten)            (None, 2432)         0           ['dropout_15[0][0]']
#
#  flatten_3 (Flatten)            (None, 64)           0           ['dropout_12[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 3904)         0           ['flatten_5[0][0]',
#                                                                   'flatten_4[0][0]',
#                                                                   'flatten_3[0][0]']
#
#  dense_2 (Dense)                (None, 16)           62480       ['concatenate_1[0][0]']
#
#  dropout_19 (Dropout)           (None, 16)           0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 1)            17          ['dropout_19[0][0]']
#
# ==================================================================================================
# Total params: 976,225
# Trainable params: 976,225
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
prediction=new_model.predict((X_test[:,:197],X_test[:,197:521],X_test[:,521:529]))


    

yout=y_test.to_numpy()    
counter=0
counter2=0
counter3=0
yout = yout. astype(int)
total=0
for i in range (prediction.shape[0]):
  if prediction[i]%1>=0.5:
    prediction[i]=int(prediction[i])+1
  else :
     prediction[i]=int(prediction[i])  

for i in range (prediction.shape[0]):
  if prediction[i]>yout[i]:
    total=total+prediction[i]-yout[i]
  else:
    total=total+yout[i]-prediction[i]

print("Hata Payı = %",total/100)
# Out:
# Hata Payı = % [16.07]

# %%
yout
