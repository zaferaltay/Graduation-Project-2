# %%
import pandas as pd
import numpy as np

urineDS=pd.read_csv("/content/drive/MyDrive/Grad2/lastUrine.csv")
urineDS=urineDS.iloc[:,1:]

from sklearn.preprocessing import StandardScaler


urineOutput=urineDS.iloc[2:,1:2]
urineInput=urineDS.iloc[2:,4:]

data = urineInput
scaler = StandardScaler()
scaler.fit(data)
urineInput=scaler.transform(data)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(urineInput, urineOutput, test_size=0.33, random_state=0)

# %%
X_train=X_train.astype(np.float64)
X_test=X_test.astype(np.float64)
y_train=y_train.astype(np.float64)
y_test=y_test.astype(np.float64)

X_train=X_train.astype(np.int64)
y_train=y_train.astype(np.int64)
X_train=X_train.astype(np.float64)
y_train=y_train.astype(np.float64)
print(y_train)
# Out:
#      Unnamed: 1
# 231        46.0
# 20         52.0
# 169        25.0
# 254        50.0
# 126        73.0
# ..          ...
# 253        30.0
# 194        60.0
# 119        61.0
# 49         61.0
# 174        62.0
#
# [201 rows x 1 columns]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Flatten,concatenate

from tensorflow.keras.optimizers import Adam
from keras.layers import Dropout
import keras
from matplotlib import pyplot as plt

model = Sequential()
model.add(Conv1D(256, 3, activation='relu', input_shape=(8, 1)))
model.add(Conv1D(256, 3, activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling1D(2))
model.add(Conv1D(128, 2, activation='relu'))
model.add(MaxPooling1D(1))
model.add(Dropout(0.25))
model.add(Conv1D(64, 1, activation='relu'))
model.add(MaxPooling1D(1))
model.add(Dropout(0.5))
model.add(Flatten())
x1=model.output



model3 = Sequential()
model3.add(Conv1D(256, 3, activation='relu', input_shape=(197, 1)))
model3.add(Conv1D(256, 3, activation='relu'))
model3.add(Dropout(0.25))
model3.add(MaxPooling1D(2))
model3.add(Conv1D(128, 3, activation='relu'))
model3.add(MaxPooling1D(2))
model3.add(Dropout(0.25))
model3.add(Conv1D(64, 3, activation='relu'))
model3.add(MaxPooling1D(2))
model3.add(Dropout(0.5))
model3.add(Flatten())
x3=model3.output

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os
import keras
from keras.models import Sequential, Model
from keras.layers import GlobalAveragePooling2D, Dense, Input, Dropout, concatenate
from keras.applications.vgg16 import VGG16
from sklearn.model_selection import train_test_split

from math import ceil
import datetime

# %%
x = concatenate([x3,x1])
#x = Sequential()(x)
x = Dense(16, activation='relu')(x) 
x = Dropout(0.2)(x)
predictions = Dense(1, activation='relu')(x)


model4 = Model(inputs=[model3.input,model.input], outputs=predictions) # Inputs go into 3 different layers
model4.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_absolute_error'])

# %%
history =model4.fit((X_train[:,:197],X_train[:,521:529]),y_train, batch_size=32, epochs=150, validation_split=0.1)
# Out:
# Epoch 1/150
# 6/6 [==============================] - 2s 233ms/step - loss: 35.5691 - mean_absolute_error: 35.5691 - val_loss: 19.6530 - val_mean_absolute_error: 19.6530
# Epoch 2/150
# 6/6 [==============================] - 1s 189ms/step - loss: 18.9758 - mean_absolute_error: 18.9758 - val_loss: 17.6946 - val_mean_absolute_error: 17.6946
# Epoch 3/150
# 6/6 [==============================] - 1s 186ms/step - loss: 17.3783 - mean_absolute_error: 17.3783 - val_loss: 21.0144 - val_mean_absolute_error: 21.0144
# Epoch 4/150
# 6/6 [==============================] - 1s 191ms/step - loss: 16.3987 - mean_absolute_error: 16.3987 - val_loss: 17.0717 - val_mean_absolute_error: 17.0717
# Epoch 5/150
# 6/6 [==============================] - 1s 195ms/step - loss: 14.2010 - mean_absolute_error: 14.2010 - val_loss: 16.9255 - val_mean_absolute_error: 16.9255
# Epoch 6/150
# 6/6 [==============================] - 1s 188ms/step - loss: 15.3483 - mean_absolute_error: 15.3483 - val_loss: 17.0845 - val_mean_absolute_error: 17.0845
# Epoch 7/150
# 6/6 [==============================] - 1s 189ms/step - loss: 14.2582 - mean_absolute_error: 14.2582 - val_loss: 16.7941 - val_mean_absolute_error: 16.7941
# Epoch 8/150
# 6/6 [==============================] - 1s 188ms/step - loss: 12.4354 - mean_absolute_error: 12.4354 - val_loss: 16.1239 - val_mean_absolute_error: 16.1239
# Epoch 9/150
# 6/6 [==============================] - 1s 194ms/step - loss: 12.3232 - mean_absolute_error: 12.3232 - val_loss: 17.0094 - val_mean_absolute_error: 17.0094
# Epoch 10/150
# 6/6 [==============================] - 1s 193ms/step - loss: 12.9670 - mean_absolute_error: 12.9670 - val_loss: 16.3207 - val_mean_absolute_error: 16.3207
# Epoch 11/150
# 6/6 [==============================] - 1s 188ms/step - loss: 13.1582 - mean_absolute_error: 13.1582 - val_loss: 16.6443 - val_mean_absolute_error: 16.6443
# Epoch 12/150
# 6/6 [==============================] - 1s 187ms/step - loss: 12.6739 - mean_absolute_error: 12.6739 - val_loss: 16.0858 - val_mean_absolute_error: 16.0858
# Epoch 13/150
# 6/6 [==============================] - 1s 188ms/step - loss: 12.5370 - mean_absolute_error: 12.5370 - val_loss: 15.5465 - val_mean_absolute_error: 15.5465
# Epoch 14/150
# 6/6 [==============================] - 1s 187ms/step - loss: 12.0382 - mean_absolute_error: 12.0382 - val_loss: 15.1660 - val_mean_absolute_error: 15.1660
# Epoch 15/150
# 6/6 [==============================] - 1s 195ms/step - loss: 11.1781 - mean_absolute_error: 11.1781 - val_loss: 15.1566 - val_mean_absolute_error: 15.1566
# Epoch 16/150
# 6/6 [==============================] - 1s 187ms/step - loss: 11.4279 - mean_absolute_error: 11.4279 - val_loss: 15.7576 - val_mean_absolute_error: 15.7576
# Epoch 17/150
# 6/6 [==============================] - 1s 188ms/step - loss: 11.2808 - mean_absolute_error: 11.2808 - val_loss: 14.8587 - val_mean_absolute_error: 14.8587
# Epoch 18/150
# 6/6 [==============================] - 1s 192ms/step - loss: 10.8513 - mean_absolute_error: 10.8513 - val_loss: 15.4231 - val_mean_absolute_error: 15.4231
# Epoch 19/150
# 6/6 [==============================] - 1s 192ms/step - loss: 12.6079 - mean_absolute_error: 12.6079 - val_loss: 16.0054 - val_mean_absolute_error: 16.0054
# Epoch 20/150
# 6/6 [==============================] - 1s 191ms/step - loss: 11.3631 - mean_absolute_error: 11.3631 - val_loss: 16.6516 - val_mean_absolute_error: 16.6516
# Epoch 21/150
# 6/6 [==============================] - 1s 195ms/step - loss: 12.4592 - mean_absolute_error: 12.4592 - val_loss: 15.5589 - val_mean_absolute_error: 15.5589
# Epoch 22/150
# 6/6 [==============================] - 1s 189ms/step - loss: 10.9797 - mean_absolute_error: 10.9797 - val_loss: 15.7529 - val_mean_absolute_error: 15.7529
# Epoch 23/150
# 6/6 [==============================] - 1s 191ms/step - loss: 12.1397 - mean_absolute_error: 12.1397 - val_loss: 17.8141 - val_mean_absolute_error: 17.8141
# Epoch 24/150
# 6/6 [==============================] - 1s 187ms/step - loss: 11.0466 - mean_absolute_error: 11.0466 - val_loss: 15.7436 - val_mean_absolute_error: 15.7436
# Epoch 25/150
# 6/6 [==============================] - 1s 189ms/step - loss: 10.0708 - mean_absolute_error: 10.0708 - val_loss: 16.1929 - val_mean_absolute_error: 16.1929
# Epoch 26/150
# 6/6 [==============================] - 1s 187ms/step - loss: 10.9805 - mean_absolute_error: 10.9805 - val_loss: 16.3180 - val_mean_absolute_error: 16.3180
# Epoch 27/150
# 6/6 [==============================] - 1s 190ms/step - loss: 11.9167 - mean_absolute_error: 11.9167 - val_loss: 16.5969 - val_mean_absolute_error: 16.5969
# Epoch 28/150
# 6/6 [==============================] - 1s 185ms/step - loss: 10.3518 - mean_absolute_error: 10.3518 - val_loss: 15.5807 - val_mean_absolute_error: 15.5807
# Epoch 29/150
# 6/6 [==============================] - 1s 190ms/step - loss: 11.2694 - mean_absolute_error: 11.2694 - val_loss: 16.8794 - val_mean_absolute_error: 16.8794
# Epoch 30/150
# 6/6 [==============================] - 1s 194ms/step - loss: 11.4209 - mean_absolute_error: 11.4209 - val_loss: 15.2185 - val_mean_absolute_error: 15.2185
# Epoch 31/150
# 6/6 [==============================] - 1s 186ms/step - loss: 11.2053 - mean_absolute_error: 11.2053 - val_loss: 17.0527 - val_mean_absolute_error: 17.0527
# Epoch 32/150
# 6/6 [==============================] - 1s 190ms/step - loss: 10.5056 - mean_absolute_error: 10.5056 - val_loss: 14.9650 - val_mean_absolute_error: 14.9650
# Epoch 33/150
# 6/6 [==============================] - 1s 189ms/step - loss: 10.7718 - mean_absolute_error: 10.7718 - val_loss: 16.1672 - val_mean_absolute_error: 16.1672
# Epoch 34/150
# 6/6 [==============================] - 1s 190ms/step - loss: 11.5551 - mean_absolute_error: 11.5551 - val_loss: 16.3959 - val_mean_absolute_error: 16.3959
# Epoch 35/150
# 6/6 [==============================] - 1s 188ms/step - loss: 11.4689 - mean_absolute_error: 11.4689 - val_loss: 15.7914 - val_mean_absolute_error: 15.7914
# Epoch 36/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.7144 - mean_absolute_error: 10.7144 - val_loss: 17.3601 - val_mean_absolute_error: 17.3601
# Epoch 37/150
# 6/6 [==============================] - 1s 189ms/step - loss: 11.8606 - mean_absolute_error: 11.8606 - val_loss: 14.8750 - val_mean_absolute_error: 14.8750
# Epoch 38/150
# 6/6 [==============================] - 1s 187ms/step - loss: 11.2109 - mean_absolute_error: 11.2109 - val_loss: 16.8678 - val_mean_absolute_error: 16.8678
# Epoch 39/150
# 6/6 [==============================] - 1s 194ms/step - loss: 11.8608 - mean_absolute_error: 11.8608 - val_loss: 14.3407 - val_mean_absolute_error: 14.3407
# Epoch 40/150
# 6/6 [==============================] - 1s 191ms/step - loss: 10.3020 - mean_absolute_error: 10.3020 - val_loss: 16.3482 - val_mean_absolute_error: 16.3482
# Epoch 41/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.4434 - mean_absolute_error: 10.4434 - val_loss: 15.0521 - val_mean_absolute_error: 15.0521
# Epoch 42/150
# 6/6 [==============================] - 1s 190ms/step - loss: 11.0145 - mean_absolute_error: 11.0145 - val_loss: 15.5928 - val_mean_absolute_error: 15.5928
# Epoch 43/150
# 6/6 [==============================] - 1s 197ms/step - loss: 11.2256 - mean_absolute_error: 11.2256 - val_loss: 15.0154 - val_mean_absolute_error: 15.0154
# Epoch 44/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.5700 - mean_absolute_error: 10.5700 - val_loss: 15.5374 - val_mean_absolute_error: 15.5374
# Epoch 45/150
# 6/6 [==============================] - 1s 192ms/step - loss: 9.5551 - mean_absolute_error: 9.5551 - val_loss: 14.9469 - val_mean_absolute_error: 14.9469
# Epoch 46/150
# 6/6 [==============================] - 1s 187ms/step - loss: 10.4478 - mean_absolute_error: 10.4478 - val_loss: 16.3145 - val_mean_absolute_error: 16.3145
# Epoch 47/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.9397 - mean_absolute_error: 10.9397 - val_loss: 14.2064 - val_mean_absolute_error: 14.2064
# Epoch 48/150
# 6/6 [==============================] - 1s 187ms/step - loss: 10.7026 - mean_absolute_error: 10.7026 - val_loss: 16.6869 - val_mean_absolute_error: 16.6869
# Epoch 49/150
# 6/6 [==============================] - 1s 189ms/step - loss: 10.7873 - mean_absolute_error: 10.7873 - val_loss: 15.4863 - val_mean_absolute_error: 15.4863
# Epoch 50/150
# 6/6 [==============================] - 1s 192ms/step - loss: 9.7754 - mean_absolute_error: 9.7754 - val_loss: 15.6894 - val_mean_absolute_error: 15.6894
# Epoch 51/150
# 6/6 [==============================] - 1s 189ms/step - loss: 11.3935 - mean_absolute_error: 11.3935 - val_loss: 15.0758 - val_mean_absolute_error: 15.0758
# Epoch 52/150
# 6/6 [==============================] - 1s 187ms/step - loss: 10.7615 - mean_absolute_error: 10.7615 - val_loss: 14.5176 - val_mean_absolute_error: 14.5176
# Epoch 53/150
# 6/6 [==============================] - 1s 191ms/step - loss: 9.9042 - mean_absolute_error: 9.9042 - val_loss: 16.7666 - val_mean_absolute_error: 16.7666
# Epoch 54/150
# 6/6 [==============================] - 1s 188ms/step - loss: 11.3185 - mean_absolute_error: 11.3185 - val_loss: 14.1673 - val_mean_absolute_error: 14.1673
# Epoch 55/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.7142 - mean_absolute_error: 10.7142 - val_loss: 16.6326 - val_mean_absolute_error: 16.6326
# Epoch 56/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.6307 - mean_absolute_error: 10.6307 - val_loss: 15.5702 - val_mean_absolute_error: 15.5702
# Epoch 57/150
# 6/6 [==============================] - 1s 189ms/step - loss: 10.0976 - mean_absolute_error: 10.0976 - val_loss: 16.3442 - val_mean_absolute_error: 16.3442
# Epoch 58/150
# 6/6 [==============================] - 1s 189ms/step - loss: 11.3402 - mean_absolute_error: 11.3402 - val_loss: 15.4300 - val_mean_absolute_error: 15.4300
# Epoch 59/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.3064 - mean_absolute_error: 10.3064 - val_loss: 16.5519 - val_mean_absolute_error: 16.5519
# Epoch 60/150
# 6/6 [==============================] - 1s 187ms/step - loss: 10.7834 - mean_absolute_error: 10.7834 - val_loss: 16.4729 - val_mean_absolute_error: 16.4729
# Epoch 61/150
# 6/6 [==============================] - 1s 187ms/step - loss: 10.4155 - mean_absolute_error: 10.4155 - val_loss: 15.4691 - val_mean_absolute_error: 15.4691
# Epoch 62/150
# 6/6 [==============================] - 1s 198ms/step - loss: 8.5882 - mean_absolute_error: 8.5882 - val_loss: 17.1299 - val_mean_absolute_error: 17.1299
# Epoch 63/150
# 6/6 [==============================] - 1s 193ms/step - loss: 9.9891 - mean_absolute_error: 9.9891 - val_loss: 16.3827 - val_mean_absolute_error: 16.3827
# Epoch 64/150
# 6/6 [==============================] - 1s 190ms/step - loss: 9.8692 - mean_absolute_error: 9.8692 - val_loss: 16.6849 - val_mean_absolute_error: 16.6849
# Epoch 65/150
# 6/6 [==============================] - 1s 190ms/step - loss: 9.8674 - mean_absolute_error: 9.8674 - val_loss: 16.2405 - val_mean_absolute_error: 16.2405
# Epoch 66/150
# 6/6 [==============================] - 1s 192ms/step - loss: 11.2819 - mean_absolute_error: 11.2819 - val_loss: 15.6989 - val_mean_absolute_error: 15.6989
# Epoch 67/150
# 6/6 [==============================] - 1s 187ms/step - loss: 9.7040 - mean_absolute_error: 9.7040 - val_loss: 16.9735 - val_mean_absolute_error: 16.9735
# Epoch 68/150
# 6/6 [==============================] - 1s 186ms/step - loss: 10.9198 - mean_absolute_error: 10.9198 - val_loss: 15.4687 - val_mean_absolute_error: 15.4687
# Epoch 69/150
# 6/6 [==============================] - 1s 186ms/step - loss: 10.1643 - mean_absolute_error: 10.1643 - val_loss: 16.4963 - val_mean_absolute_error: 16.4963
# Epoch 70/150
# 6/6 [==============================] - 1s 193ms/step - loss: 10.2159 - mean_absolute_error: 10.2159 - val_loss: 17.1790 - val_mean_absolute_error: 17.1790
# Epoch 71/150
# 6/6 [==============================] - 1s 186ms/step - loss: 10.9758 - mean_absolute_error: 10.9758 - val_loss: 16.0610 - val_mean_absolute_error: 16.0610
# Epoch 72/150
# 6/6 [==============================] - 1s 192ms/step - loss: 11.1669 - mean_absolute_error: 11.1669 - val_loss: 17.3894 - val_mean_absolute_error: 17.3894
# Epoch 73/150
# 6/6 [==============================] - 1s 190ms/step - loss: 10.4061 - mean_absolute_error: 10.4061 - val_loss: 16.3156 - val_mean_absolute_error: 16.3156
# Epoch 74/150
# 6/6 [==============================] - 1s 191ms/step - loss: 10.5447 - mean_absolute_error: 10.5447 - val_loss: 15.8414 - val_mean_absolute_error: 15.8414
# Epoch 75/150
# 6/6 [==============================] - 1s 189ms/step - loss: 10.1529 - mean_absolute_error: 10.1529 - val_loss: 17.4971 - val_mean_absolute_error: 17.4971
# Epoch 76/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.0250 - mean_absolute_error: 10.0250 - val_loss: 14.9950 - val_mean_absolute_error: 14.9950
# Epoch 77/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.6238 - mean_absolute_error: 10.6238 - val_loss: 17.1030 - val_mean_absolute_error: 17.1030
# Epoch 78/150
# 6/6 [==============================] - 1s 192ms/step - loss: 9.9769 - mean_absolute_error: 9.9769 - val_loss: 14.7012 - val_mean_absolute_error: 14.7012
# Epoch 79/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.7140 - mean_absolute_error: 10.7140 - val_loss: 17.9984 - val_mean_absolute_error: 17.9984
# Epoch 80/150
# 6/6 [==============================] - 1s 194ms/step - loss: 10.5661 - mean_absolute_error: 10.5661 - val_loss: 14.6379 - val_mean_absolute_error: 14.6379
# Epoch 81/150
# 6/6 [==============================] - 1s 191ms/step - loss: 10.5189 - mean_absolute_error: 10.5189 - val_loss: 17.3228 - val_mean_absolute_error: 17.3228
# Epoch 82/150
# 6/6 [==============================] - 1s 195ms/step - loss: 11.7814 - mean_absolute_error: 11.7814 - val_loss: 15.3897 - val_mean_absolute_error: 15.3897
# Epoch 83/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.5575 - mean_absolute_error: 10.5575 - val_loss: 15.2875 - val_mean_absolute_error: 15.2875
# Epoch 84/150
# 6/6 [==============================] - 1s 189ms/step - loss: 11.2103 - mean_absolute_error: 11.2103 - val_loss: 16.0963 - val_mean_absolute_error: 16.0963
# Epoch 85/150
# 6/6 [==============================] - 1s 188ms/step - loss: 9.8984 - mean_absolute_error: 9.8984 - val_loss: 15.7132 - val_mean_absolute_error: 15.7132
# Epoch 86/150
# 6/6 [==============================] - 1s 192ms/step - loss: 9.5767 - mean_absolute_error: 9.5767 - val_loss: 16.3432 - val_mean_absolute_error: 16.3432
# Epoch 87/150
# 6/6 [==============================] - 1s 189ms/step - loss: 10.0912 - mean_absolute_error: 10.0912 - val_loss: 15.4220 - val_mean_absolute_error: 15.4220
# Epoch 88/150
# 6/6 [==============================] - 1s 192ms/step - loss: 9.5127 - mean_absolute_error: 9.5127 - val_loss: 17.2506 - val_mean_absolute_error: 17.2506
# Epoch 89/150
# 6/6 [==============================] - 1s 193ms/step - loss: 10.2182 - mean_absolute_error: 10.2182 - val_loss: 15.4228 - val_mean_absolute_error: 15.4228
# Epoch 90/150
# 6/6 [==============================] - 1s 193ms/step - loss: 10.9876 - mean_absolute_error: 10.9876 - val_loss: 15.9327 - val_mean_absolute_error: 15.9327
# Epoch 91/150
# 6/6 [==============================] - 1s 199ms/step - loss: 10.1970 - mean_absolute_error: 10.1970 - val_loss: 15.8444 - val_mean_absolute_error: 15.8444
# Epoch 92/150
# 6/6 [==============================] - 1s 185ms/step - loss: 9.8308 - mean_absolute_error: 9.8308 - val_loss: 16.0503 - val_mean_absolute_error: 16.0503
# Epoch 93/150
# 6/6 [==============================] - 1s 187ms/step - loss: 9.8254 - mean_absolute_error: 9.8254 - val_loss: 16.4370 - val_mean_absolute_error: 16.4370
# Epoch 94/150
# 6/6 [==============================] - 1s 194ms/step - loss: 10.1265 - mean_absolute_error: 10.1265 - val_loss: 16.2560 - val_mean_absolute_error: 16.2560
# Epoch 95/150
# 6/6 [==============================] - 1s 194ms/step - loss: 10.2432 - mean_absolute_error: 10.2432 - val_loss: 15.6058 - val_mean_absolute_error: 15.6058
# Epoch 96/150
# 6/6 [==============================] - 1s 194ms/step - loss: 8.9498 - mean_absolute_error: 8.9498 - val_loss: 16.7684 - val_mean_absolute_error: 16.7684
# Epoch 97/150
# 6/6 [==============================] - 1s 192ms/step - loss: 8.9559 - mean_absolute_error: 8.9559 - val_loss: 15.2101 - val_mean_absolute_error: 15.2101
# Epoch 98/150
# 6/6 [==============================] - 1s 189ms/step - loss: 10.3020 - mean_absolute_error: 10.3020 - val_loss: 17.3057 - val_mean_absolute_error: 17.3057
# Epoch 99/150
# 6/6 [==============================] - 1s 193ms/step - loss: 9.5224 - mean_absolute_error: 9.5224 - val_loss: 15.7472 - val_mean_absolute_error: 15.7472
# Epoch 100/150
# 6/6 [==============================] - 1s 184ms/step - loss: 10.7411 - mean_absolute_error: 10.7411 - val_loss: 17.0848 - val_mean_absolute_error: 17.0848
# Epoch 101/150
# 6/6 [==============================] - 1s 187ms/step - loss: 10.3143 - mean_absolute_error: 10.3143 - val_loss: 16.9006 - val_mean_absolute_error: 16.9006
# Epoch 102/150
# 6/6 [==============================] - 1s 190ms/step - loss: 9.2409 - mean_absolute_error: 9.2409 - val_loss: 15.3623 - val_mean_absolute_error: 15.3623
# Epoch 103/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.1891 - mean_absolute_error: 10.1891 - val_loss: 17.0909 - val_mean_absolute_error: 17.0909
# Epoch 104/150
# 6/6 [==============================] - 1s 193ms/step - loss: 10.5789 - mean_absolute_error: 10.5789 - val_loss: 14.6440 - val_mean_absolute_error: 14.6440
# Epoch 105/150
# 6/6 [==============================] - 1s 192ms/step - loss: 10.9167 - mean_absolute_error: 10.9167 - val_loss: 17.4356 - val_mean_absolute_error: 17.4356
# Epoch 106/150
# 6/6 [==============================] - 1s 186ms/step - loss: 9.9408 - mean_absolute_error: 9.9408 - val_loss: 14.5261 - val_mean_absolute_error: 14.5261
# Epoch 107/150
# 6/6 [==============================] - 1s 193ms/step - loss: 10.9503 - mean_absolute_error: 10.9503 - val_loss: 15.5401 - val_mean_absolute_error: 15.5401
# Epoch 108/150
# 6/6 [==============================] - 1s 187ms/step - loss: 9.3547 - mean_absolute_error: 9.3547 - val_loss: 15.3316 - val_mean_absolute_error: 15.3316
# Epoch 109/150
# 6/6 [==============================] - 1s 191ms/step - loss: 9.7174 - mean_absolute_error: 9.7174 - val_loss: 15.8502 - val_mean_absolute_error: 15.8502
# Epoch 110/150
# 6/6 [==============================] - 1s 189ms/step - loss: 9.0967 - mean_absolute_error: 9.0967 - val_loss: 15.7804 - val_mean_absolute_error: 15.7804
# Epoch 111/150
# 6/6 [==============================] - 1s 190ms/step - loss: 9.1178 - mean_absolute_error: 9.1178 - val_loss: 16.5721 - val_mean_absolute_error: 16.5721
# Epoch 112/150
# 6/6 [==============================] - 1s 189ms/step - loss: 11.1973 - mean_absolute_error: 11.1973 - val_loss: 15.3790 - val_mean_absolute_error: 15.3790
# Epoch 113/150
# 6/6 [==============================] - 1s 194ms/step - loss: 10.7945 - mean_absolute_error: 10.7945 - val_loss: 16.3870 - val_mean_absolute_error: 16.3870
# Epoch 114/150
# 6/6 [==============================] - 1s 193ms/step - loss: 9.9883 - mean_absolute_error: 9.9883 - val_loss: 16.0425 - val_mean_absolute_error: 16.0425
# Epoch 115/150
# 6/6 [==============================] - 1s 192ms/step - loss: 11.0461 - mean_absolute_error: 11.0461 - val_loss: 14.9472 - val_mean_absolute_error: 14.9472
# Epoch 116/150
# 6/6 [==============================] - 1s 195ms/step - loss: 10.0843 - mean_absolute_error: 10.0843 - val_loss: 16.2215 - val_mean_absolute_error: 16.2215
# Epoch 117/150
# 6/6 [==============================] - 1s 190ms/step - loss: 10.1272 - mean_absolute_error: 10.1272 - val_loss: 14.9810 - val_mean_absolute_error: 14.9810
# Epoch 118/150
# 6/6 [==============================] - 1s 190ms/step - loss: 9.4753 - mean_absolute_error: 9.4753 - val_loss: 15.2882 - val_mean_absolute_error: 15.2882
# Epoch 119/150
# 6/6 [==============================] - 1s 191ms/step - loss: 9.5716 - mean_absolute_error: 9.5716 - val_loss: 16.3540 - val_mean_absolute_error: 16.3540
# Epoch 120/150
# 6/6 [==============================] - 1s 191ms/step - loss: 9.4807 - mean_absolute_error: 9.4807 - val_loss: 15.1607 - val_mean_absolute_error: 15.1607
# Epoch 121/150
# 6/6 [==============================] - 1s 191ms/step - loss: 11.6899 - mean_absolute_error: 11.6899 - val_loss: 15.1752 - val_mean_absolute_error: 15.1752
# Epoch 122/150
# 6/6 [==============================] - 1s 190ms/step - loss: 10.5883 - mean_absolute_error: 10.5883 - val_loss: 18.1074 - val_mean_absolute_error: 18.1074
# Epoch 123/150
# 6/6 [==============================] - 1s 192ms/step - loss: 11.0266 - mean_absolute_error: 11.0266 - val_loss: 14.6110 - val_mean_absolute_error: 14.6110
# Epoch 124/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.2007 - mean_absolute_error: 10.2007 - val_loss: 17.1649 - val_mean_absolute_error: 17.1649
# Epoch 125/150
# 6/6 [==============================] - 1s 195ms/step - loss: 11.1173 - mean_absolute_error: 11.1173 - val_loss: 15.2188 - val_mean_absolute_error: 15.2188
# Epoch 126/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.0800 - mean_absolute_error: 10.0800 - val_loss: 15.0747 - val_mean_absolute_error: 15.0747
# Epoch 127/150
# 6/6 [==============================] - 1s 191ms/step - loss: 9.6028 - mean_absolute_error: 9.6028 - val_loss: 16.2557 - val_mean_absolute_error: 16.2557
# Epoch 128/150
# 6/6 [==============================] - 1s 192ms/step - loss: 11.2269 - mean_absolute_error: 11.2269 - val_loss: 14.3360 - val_mean_absolute_error: 14.3360
# Epoch 129/150
# 6/6 [==============================] - 1s 193ms/step - loss: 9.6844 - mean_absolute_error: 9.6844 - val_loss: 15.7450 - val_mean_absolute_error: 15.7450
# Epoch 130/150
# 6/6 [==============================] - 1s 193ms/step - loss: 9.7728 - mean_absolute_error: 9.7728 - val_loss: 15.4258 - val_mean_absolute_error: 15.4258
# Epoch 131/150
# 6/6 [==============================] - 1s 189ms/step - loss: 9.9178 - mean_absolute_error: 9.9178 - val_loss: 14.6957 - val_mean_absolute_error: 14.6957
# Epoch 132/150
# 6/6 [==============================] - 1s 194ms/step - loss: 10.1738 - mean_absolute_error: 10.1738 - val_loss: 14.8429 - val_mean_absolute_error: 14.8429
# Epoch 133/150
# 6/6 [==============================] - 1s 195ms/step - loss: 10.0304 - mean_absolute_error: 10.0304 - val_loss: 15.1056 - val_mean_absolute_error: 15.1056
# Epoch 134/150
# 6/6 [==============================] - 1s 199ms/step - loss: 9.4877 - mean_absolute_error: 9.4877 - val_loss: 14.5999 - val_mean_absolute_error: 14.5999
# Epoch 135/150
# 6/6 [==============================] - 1s 192ms/step - loss: 11.0513 - mean_absolute_error: 11.0513 - val_loss: 15.0452 - val_mean_absolute_error: 15.0452
# Epoch 136/150
# 6/6 [==============================] - 1s 188ms/step - loss: 10.0705 - mean_absolute_error: 10.0705 - val_loss: 16.3214 - val_mean_absolute_error: 16.3214
# Epoch 137/150
# 6/6 [==============================] - 1s 190ms/step - loss: 10.0421 - mean_absolute_error: 10.0421 - val_loss: 15.3637 - val_mean_absolute_error: 15.3637
# Epoch 138/150
# 6/6 [==============================] - 1s 191ms/step - loss: 9.8295 - mean_absolute_error: 9.8295 - val_loss: 14.7409 - val_mean_absolute_error: 14.7409
# Epoch 139/150
# 6/6 [==============================] - 1s 188ms/step - loss: 9.6769 - mean_absolute_error: 9.6769 - val_loss: 16.2899 - val_mean_absolute_error: 16.2899
# Epoch 140/150
# 6/6 [==============================] - 1s 190ms/step - loss: 8.8791 - mean_absolute_error: 8.8791 - val_loss: 14.9630 - val_mean_absolute_error: 14.9630
# Epoch 141/150
# 6/6 [==============================] - 1s 192ms/step - loss: 9.5275 - mean_absolute_error: 9.5275 - val_loss: 15.1874 - val_mean_absolute_error: 15.1874
# Epoch 142/150
# 6/6 [==============================] - 1s 194ms/step - loss: 9.1336 - mean_absolute_error: 9.1336 - val_loss: 15.4493 - val_mean_absolute_error: 15.4493
# Epoch 143/150
# 6/6 [==============================] - 1s 196ms/step - loss: 9.1749 - mean_absolute_error: 9.1749 - val_loss: 16.1038 - val_mean_absolute_error: 16.1038
# Epoch 144/150
# 6/6 [==============================] - 1s 192ms/step - loss: 9.4111 - mean_absolute_error: 9.4111 - val_loss: 15.2454 - val_mean_absolute_error: 15.2454
# Epoch 145/150
# 6/6 [==============================] - 1s 190ms/step - loss: 10.3578 - mean_absolute_error: 10.3578 - val_loss: 15.6844 - val_mean_absolute_error: 15.6844
# Epoch 146/150
# 6/6 [==============================] - 1s 196ms/step - loss: 9.9835 - mean_absolute_error: 9.9835 - val_loss: 14.9157 - val_mean_absolute_error: 14.9157
# Epoch 147/150
# 6/6 [==============================] - 1s 196ms/step - loss: 9.0199 - mean_absolute_error: 9.0199 - val_loss: 15.5899 - val_mean_absolute_error: 15.5899
# Epoch 148/150
# 6/6 [==============================] - 1s 195ms/step - loss: 9.9958 - mean_absolute_error: 9.9958 - val_loss: 15.6961 - val_mean_absolute_error: 15.6961
# Epoch 149/150
# 6/6 [==============================] - 1s 199ms/step - loss: 10.3165 - mean_absolute_error: 10.3165 - val_loss: 14.9248 - val_mean_absolute_error: 14.9248
# Epoch 150/150
# 6/6 [==============================] - 1s 197ms/step - loss: 9.6365 - mean_absolute_error: 9.6365 - val_loss: 16.1103 - val_mean_absolute_error: 16.1103

# %%
import matplotlib.pyplot as plt
print(history.history.keys())

plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
import os

import tensorflow as tf
from tensorflow import keras

print(tf.version.VERSION)
model4.save('/content/drive/MyDrive/Grad2Models/yasNmrClinic')
# Out:
# 2.8.2
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Grad2Models/yasNmrClinic/assets

# %%
new_model = tf.keras.models.load_model('/content/drive/MyDrive/Grad2Models/yasNmrClinic', compile=False)

# Check its architecture
new_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  conv1d_4_input (InputLayer)    [(None, 197, 1)]     0           []
#
#  conv1d_input (InputLayer)      [(None, 8, 1)]       0           []
#
#  conv1d_4 (Conv1D)              (None, 195, 256)     1024        ['conv1d_4_input[0][0]']
#
#  conv1d (Conv1D)                (None, 6, 256)       1024        ['conv1d_input[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 193, 256)     196864      ['conv1d_4[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 4, 256)       196864      ['conv1d[0][0]']
#
#  dropout_3 (Dropout)            (None, 193, 256)     0           ['conv1d_5[0][0]']
#
#  dropout (Dropout)              (None, 4, 256)       0           ['conv1d_1[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 96, 256)     0           ['dropout_3[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 2, 256)       0           ['dropout[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 94, 128)      98432       ['max_pooling1d_3[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 1, 128)       65664       ['max_pooling1d[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 47, 128)     0           ['conv1d_6[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 1, 128)      0           ['conv1d_2[0][0]']
#
#  dropout_4 (Dropout)            (None, 47, 128)      0           ['max_pooling1d_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 1, 128)       0           ['max_pooling1d_1[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 45, 64)       24640       ['dropout_4[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 1, 64)        8256        ['dropout_1[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 22, 64)      0           ['conv1d_7[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 1, 64)       0           ['conv1d_3[0][0]']
#
#  dropout_5 (Dropout)            (None, 22, 64)       0           ['max_pooling1d_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 1, 64)        0           ['max_pooling1d_2[0][0]']
#
#  flatten_1 (Flatten)            (None, 1408)         0           ['dropout_5[0][0]']
#
#  flatten (Flatten)              (None, 64)           0           ['dropout_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 1472)         0           ['flatten_1[0][0]',
#                                                                   'flatten[0][0]']
#
#  dense_4 (Dense)                (None, 16)           23568       ['concatenate_2[0][0]']
#
#  dropout_8 (Dropout)            (None, 16)           0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 1)            17          ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 616,353
# Trainable params: 616,353
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
prediction=new_model.predict((X_test[:,:197],X_test[:,521:529]))


    

yout=y_test.to_numpy()    
counter=0
counter2=0
counter3=0
yout = yout. astype(int)
total=0
for i in range (prediction.shape[0]):
  if prediction[i]%1>=0.5:
    prediction[i]=int(prediction[i])+1
  else :
     prediction[i]=int(prediction[i])  

for i in range (prediction.shape[0]):
  if prediction[i]>yout[i]:
    total=total+prediction[i]-yout[i]
  else:
    total=total+yout[i]-prediction[i]

print("Hata Payı = %",total/100)
# Out:
# Hata Payı = % [18.13]
